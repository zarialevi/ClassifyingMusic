# %%
import pandas as pd
import json

from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pprint
import requests

import re

pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 90)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

client_credentials_manager = SpotifyClientCredentials(client_id='472d9fe420af4222b7afdd11b9578446', client_secret='518bc9207d064855be7f6300ca080c76')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

import api
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # API Calls from Playlist

# %%
oath = api.get_auth()
playlists = api.get_playlists()

# %%
tracks_df = api.get_tracks_from_playlist(playlists)

# %%
tracks_df
# Out:
#              track_name            artist                           album  \
# 0    Tell It Like It Is     Aaron Neville  The Very Best Of Aaron Neville
# 1         Body Language     Anthony David               As Above So Below
# 2             Everybody  Anthony Hamilton           Ain't Nobody Worryin'
# 3         Special Guest      Anthony Rich             Pure Lovers, Vol. 2
# 4        Back To Africa             Aswad                           Aswad
# ..                  ...               ...                             ...
# 195       Happy Pum Pum       Vybz Kartel          Happy Pum Pum - Single
# 196          Bring Life            Kalado                Seduction Riddim
# 197            Bawl Out      Dovey Magnum               Rum & Boom Riddim
# 198         Belt Buckle            Mavado                     Belt Buckle
# 199      You're Perfect      Charly Black                  You're Perfect
#
#     release_date  explicit                track_id  \
# 0     2000-01-11     False  66BjgQodHebiX5QGpBAjyQ
# 1     2011-03-22     False  5tyAVAPIOiG6LJaeWNVWds
# 2     2005-12-13     False  1epUp0pgKLddapHeNU9ee1
# 3     2009-06-01     False  01rxaavCYWlFIHJJdF4PTT
# 4     1976-01-01     False  05pKNQGaN3xA8jbyibUrlZ
# ..           ...       ...                     ...
# 195   2014-04-29     False  2iGyVlivbKEkJDTCwrx29C
# 196   2013-06-11      True  1zSyCSI9cOYbb56mRA5HhY
# 197   2017-09-29      True  0ua1i6l0wCu6gzK6pqnjaK
# 198   2017-02-24      True  5EPYq36XfrGMOmHMBnh8xf
# 199   2017-10-20     False  4iSWQ5Eadn5tZvvG9XNzYN
#
#                                 track_uri
# 0    spotify:track:66BjgQodHebiX5QGpBAjyQ
# 1    spotify:track:5tyAVAPIOiG6LJaeWNVWds
# 2    spotify:track:1epUp0pgKLddapHeNU9ee1
# 3    spotify:track:01rxaavCYWlFIHJJdF4PTT
# 4    spotify:track:05pKNQGaN3xA8jbyibUrlZ
# ..                                    ...
# 195  spotify:track:2iGyVlivbKEkJDTCwrx29C
# 196  spotify:track:1zSyCSI9cOYbb56mRA5HhY
# 197  spotify:track:0ua1i6l0wCu6gzK6pqnjaK
# 198  spotify:track:5EPYq36XfrGMOmHMBnh8xf
# 199  spotify:track:4iSWQ5Eadn5tZvvG9XNzYN
#
# [200 rows x 7 columns]

# %%
feats = api.get_feats(tracks_df)
# Out:
# retrying ...2secs
# retrying ...1secs
# retrying ...3secs
# retrying ...1secs

# %%
feats.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.542   0.461    2    -7.071     0       0.0286        0.4650
# 1         0.691   0.536    9    -8.522     1       0.1680        0.0754
# 2         0.613   0.680    6    -6.708     0       0.2360        0.0560
# 3         0.833   0.309    7   -10.400     1       0.1050        0.0987
# 4         0.794   0.156    9   -18.988     0       0.4320        0.4730
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.1770    0.629   94.214  audio_features
# 1          0.000563    0.1250    0.818  142.053  audio_features
# 2          0.000000    0.3260    0.743   74.848  audio_features
# 3          0.000009    0.0819    0.927   87.047  audio_features
# 4          0.799000    0.0886    0.719  127.430  audio_features
#
#                        id                                   uri  \
# 0  66BjgQodHebiX5QGpBAjyQ  spotify:track:66BjgQodHebiX5QGpBAjyQ
# 1  5tyAVAPIOiG6LJaeWNVWds  spotify:track:5tyAVAPIOiG6LJaeWNVWds
# 2  1epUp0pgKLddapHeNU9ee1  spotify:track:1epUp0pgKLddapHeNU9ee1
# 3  01rxaavCYWlFIHJJdF4PTT  spotify:track:01rxaavCYWlFIHJJdF4PTT
# 4  05pKNQGaN3xA8jbyibUrlZ  spotify:track:05pKNQGaN3xA8jbyibUrlZ
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/66BjgQodHebi...
# 1  https://api.spotify.com/v1/tracks/5tyAVAPIOiG6...
# 2  https://api.spotify.com/v1/tracks/1epUp0pgKLdd...
# 3  https://api.spotify.com/v1/tracks/01rxaavCYWlF...
# 4  https://api.spotify.com/v1/tracks/05pKNQGaN3xA...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/66Bj...       164560
# 1  https://api.spotify.com/v1/audio-analysis/5tyA...       273400
# 2  https://api.spotify.com/v1/audio-analysis/1epU...       251000
# 3  https://api.spotify.com/v1/audio-analysis/01rx...       234867
# 4  https://api.spotify.com/v1/audio-analysis/05pK...       336773
#
#    time_signature
# 0               3
# 1               4
# 2               4
# 3               4
# 4               4

# %%
feats.index = feats['id']
tracks_df.index = tracks_df['track_id']

# %%
full_df = tracks_df.join(feats)

# %%
full_df['genre'] = 'reggae'

# %%
full_df.to_csv('working.csv')

# %% [markdown]
# # Bashment

# %%
df = pd.read_csv('soca_working.csv')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1763, step=1)

# %%
df.dropna(inplace=True)
# df.drop(columns=['genre','Unnamed: 0'], inplace=True)
# df.reset_index(drop=True, inplace=True)
# df.drop(labels = [235, 240], axis=0, inplace=True)
# df.reset_index(drop=True, inplace=True)

# %%
ax = api.get_feats(df)
# Out:
# retrying ...2secs
# retrying ...3secs
# retrying ...1secs
# retrying ...3secs
# retrying ...1secs
# retrying ...1secs
# retrying ...3secs
# retrying ...1secs

# %%
ax
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.822   0.775   10    -3.612     0       0.0592       0.00261
# 1            0.410   0.938    0    -4.124     1       0.2080       0.04460
# 2            0.769   0.869    1    -5.244     1       0.1410       0.11500
# 3            0.679   0.788    9    -6.945     1       0.0418       0.00189
# 4            0.762   0.724    9    -7.340     0       0.1320       0.01140
# ...            ...     ...  ...       ...   ...          ...           ...
# 1749         0.506   0.763    0    -5.770     1       0.1540       0.24600
# 1750         0.790   0.921    9    -4.935     0       0.1720       0.11100
# 1751         0.520   0.869   11    -4.419     0       0.2490       0.00987
# 1752         0.803   0.908   11    -2.916     1       0.1550       0.01620
# 1753         0.759   0.891    7    -4.804     1       0.0976       0.20900
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.0890    0.897  110.022  audio_features
# 1             0.000000    0.4560    0.724  189.041  audio_features
# 2             0.000034    0.1760    0.483  129.933  audio_features
# 3             0.000000    0.3390    0.502  136.017  audio_features
# 4             0.000082    0.0696    0.810  125.017  audio_features
# ...                ...       ...      ...      ...             ...
# 1749          0.000000    0.1020    0.504   69.859  audio_features
# 1750          0.000000    0.0748    0.704  127.996  audio_features
# 1751          0.000000    0.2340    0.868  191.261  audio_features
# 1752          0.000000    0.0790    0.601  127.944  audio_features
# 1753          0.000000    0.0518    0.923  118.073  audio_features
#
#                           id                                   uri  \
# 0     6Ix1AiOaD5wUGXsGop0OzR  spotify:track:6Ix1AiOaD5wUGXsGop0OzR
# 1     2LbGlvcmB7pUZ8AavRW6aR  spotify:track:2LbGlvcmB7pUZ8AavRW6aR
# 2     518KfnjvzlxQrwQg8an3KW  spotify:track:518KfnjvzlxQrwQg8an3KW
# 3     636UH9tWUnWd4ZkWEb1ZG8  spotify:track:636UH9tWUnWd4ZkWEb1ZG8
# 4     5cNNbxTvAZsB9OQnLU2caR  spotify:track:5cNNbxTvAZsB9OQnLU2caR
# ...                      ...                                   ...
# 1749  339f700JtCpTrNWLZrgRV1  spotify:track:339f700JtCpTrNWLZrgRV1
# 1750  7h6GwtJG2EgQoQzYATWFgM  spotify:track:7h6GwtJG2EgQoQzYATWFgM
# 1751  0vgPJExzDVZoqdkBzeOV0P  spotify:track:0vgPJExzDVZoqdkBzeOV0P
# 1752  2UC8x4vO3eVXIurgaKMW9d  spotify:track:2UC8x4vO3eVXIurgaKMW9d
# 1753  3RYPOYutIL3aWa1JoBWeWg  spotify:track:3RYPOYutIL3aWa1JoBWeWg
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/6Ix1AiOaD5wU...
# 1     https://api.spotify.com/v1/tracks/2LbGlvcmB7pU...
# 2     https://api.spotify.com/v1/tracks/518KfnjvzlxQ...
# 3     https://api.spotify.com/v1/tracks/636UH9tWUnWd...
# 4     https://api.spotify.com/v1/tracks/5cNNbxTvAZsB...
# ...                                                 ...
# 1749  https://api.spotify.com/v1/tracks/339f700JtCpT...
# 1750  https://api.spotify.com/v1/tracks/7h6GwtJG2EgQ...
# 1751  https://api.spotify.com/v1/tracks/0vgPJExzDVZo...
# 1752  https://api.spotify.com/v1/tracks/2UC8x4vO3eVX...
# 1753  https://api.spotify.com/v1/tracks/3RYPOYutIL3a...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/6Ix1...       196364
# 1     https://api.spotify.com/v1/audio-analysis/2LbG...       234405
# 2     https://api.spotify.com/v1/audio-analysis/518K...       225229
# 3     https://api.spotify.com/v1/audio-analysis/636U...       231132
# 4     https://api.spotify.com/v1/audio-analysis/5cNN...       218932
# ...                                                 ...          ...
# 1749  https://api.spotify.com/v1/audio-analysis/339f...       262014
# 1750  https://api.spotify.com/v1/audio-analysis/7h6G...       212812
# 1751  https://api.spotify.com/v1/audio-analysis/0vgP...       215625
# 1752  https://api.spotify.com/v1/audio-analysis/2UC8...       244773
# 1753  https://api.spotify.com/v1/audio-analysis/3RYP...       199703
#
#       time_signature
# 0                  4
# 1                  3
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1749               5
# 1750               4
# 1751               3
# 1752               4
# 1753               4
#
# [1754 rows x 18 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1756, step=1)

# %%
data = sp.audio_features(tracks = df.track_id[0])

# %%
data[0]
# Out:
# {'danceability': 0.822,
#  'energy': 0.775,
#  'key': 10,
#  'loudness': -3.612,
#  'mode': 0,
#  'speechiness': 0.0592,
#  'acousticness': 0.00261,
#  'instrumentalness': 0,
#  'liveness': 0.089,
#  'valence': 0.897,
#  'tempo': 110.022,
#  'type': 'audio_features',
#  'id': '6Ix1AiOaD5wUGXsGop0OzR',
#  'uri': 'spotify:track:6Ix1AiOaD5wUGXsGop0OzR',
#  'track_href': 'https://api.spotify.com/v1/tracks/6Ix1AiOaD5wUGXsGop0OzR',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Ix1AiOaD5wUGXsGop0OzR',
#  'duration_ms': 196364,
#  'time_signature': 4}

# %%
ax.index = ax['id']
df.index = df['track_id']

# %%
full_df_ = df.join(ax)

# %%
full_df_
# Out:
#                         Unnamed: 0                      track_name  \
# 00A8hsKelAI5N7bmcbvn9v        1119                         So Long
# 00BBC45AUahDMdYaJ6wjxp         797                         Mash Up
# 00v3qhEMB8Z8D5PU2LpDFK         832                         Toc Tic
# 01NRErhQZIau5ebhdXMhGs        1088                    Dom Pérignon
# 01NjsQ8VVcaPNZPIfzhhb1        1504        X Games - Acoustic Intro
# ...                            ...                             ...
# 7vS7knISRY4QEk6vzeOGk3        1496  Body Talk (feat. Chris Hierro)
# 7vy0S9WfaUoC4SZE6DO65M          51                        Activate
# 7xMICFkbPw6ClC4jENSX3U         383                     Kiss & Tell
# 7xW9kuak6ViVF8Z9Ih15ZM        1398                      Work It Up
# 7xiaGjbAhXFO8bkjLyfdcN         367       Everybody Fucking Ya Gyal
#
#                                  artist                           album  \
# 00A8hsKelAI5N7bmcbvn9v     Nadia Batson                   Get Soca 2019
# 00BBC45AUahDMdYaJ6wjxp           Destra              Queen of Bacchanal
# 00v3qhEMB8Z8D5PU2LpDFK        Marzville                 Force It Riddim
# 01NRErhQZIau5ebhdXMhGs          Aidonia                    Dom Pérignon
# 01NjsQ8VVcaPNZPIfzhhb1  DJ Private Ryan              The Fizzle Project
# ...                                 ...                             ...
# 7vS7knISRY4QEk6vzeOGk3              Kes  Body Talk (feat. Chris Hierro)
# 7vy0S9WfaUoC4SZE6DO65M  Skinny Fabulous                        Activate
# 7xMICFkbPw6ClC4jENSX3U  Patrice Roberts                  Sexting Riddim
# 7xW9kuak6ViVF8Z9Ih15ZM      Pupa Leendi       De Boss Riddim: Soca 2015
# 7xiaGjbAhXFO8bkjLyfdcN     Young Bredda       Everybody Fucking Ya Gyal
#
#                        release_date  explicit                track_id  \
# 00A8hsKelAI5N7bmcbvn9v   2019-02-22     False  00A8hsKelAI5N7bmcbvn9v
# 00BBC45AUahDMdYaJ6wjxp   2014-04-08     False  00BBC45AUahDMdYaJ6wjxp
# 00v3qhEMB8Z8D5PU2LpDFK   2016-12-16     False  00v3qhEMB8Z8D5PU2LpDFK
# 01NRErhQZIau5ebhdXMhGs   2018-12-20      True  01NRErhQZIau5ebhdXMhGs
# 01NjsQ8VVcaPNZPIfzhhb1   2019-12-02     False  01NjsQ8VVcaPNZPIfzhhb1
# ...                             ...       ...                     ...
# 7vS7knISRY4QEk6vzeOGk3   2015-11-24     False  7vS7knISRY4QEk6vzeOGk3
# 7vy0S9WfaUoC4SZE6DO65M   2018-02-16     False  7vy0S9WfaUoC4SZE6DO65M
# 7xMICFkbPw6ClC4jENSX3U   2019-06-14     False  7xMICFkbPw6ClC4jENSX3U
# 7xW9kuak6ViVF8Z9Ih15ZM   2015-01-15     False  7xW9kuak6ViVF8Z9Ih15ZM
# 7xiaGjbAhXFO8bkjLyfdcN   2019-08-02      True  7xiaGjbAhXFO8bkjLyfdcN
#
#                                                    track_uri genre  \
# 00A8hsKelAI5N7bmcbvn9v  spotify:track:00A8hsKelAI5N7bmcbvn9v  soca
# 00BBC45AUahDMdYaJ6wjxp  spotify:track:00BBC45AUahDMdYaJ6wjxp  soca
# 00v3qhEMB8Z8D5PU2LpDFK  spotify:track:00v3qhEMB8Z8D5PU2LpDFK  soca
# 01NRErhQZIau5ebhdXMhGs  spotify:track:01NRErhQZIau5ebhdXMhGs  soca
# 01NjsQ8VVcaPNZPIfzhhb1  spotify:track:01NjsQ8VVcaPNZPIfzhhb1  soca
# ...                                                      ...   ...
# 7vS7knISRY4QEk6vzeOGk3  spotify:track:7vS7knISRY4QEk6vzeOGk3  soca
# 7vy0S9WfaUoC4SZE6DO65M  spotify:track:7vy0S9WfaUoC4SZE6DO65M  soca
# 7xMICFkbPw6ClC4jENSX3U  spotify:track:7xMICFkbPw6ClC4jENSX3U  soca
# 7xW9kuak6ViVF8Z9Ih15ZM  spotify:track:7xW9kuak6ViVF8Z9Ih15ZM  soca
# 7xiaGjbAhXFO8bkjLyfdcN  spotify:track:7xiaGjbAhXFO8bkjLyfdcN  soca
#
#                         danceability  energy  key  loudness  mode  \
# 00A8hsKelAI5N7bmcbvn9v         0.859   0.930  6.0    -3.794   1.0
# 00BBC45AUahDMdYaJ6wjxp         0.768   0.942  8.0    -3.153   1.0
# 00v3qhEMB8Z8D5PU2LpDFK         0.891   0.858  2.0    -4.668   1.0
# 01NRErhQZIau5ebhdXMhGs         0.800   0.848  1.0    -6.937   1.0
# 01NjsQ8VVcaPNZPIfzhhb1         0.768   0.824  5.0    -4.254   0.0
# ...                              ...     ...  ...       ...   ...
# 7vS7knISRY4QEk6vzeOGk3         0.754   0.932  8.0    -5.073   1.0
# 7vy0S9WfaUoC4SZE6DO65M         0.642   0.853  6.0    -4.059   1.0
# 7xMICFkbPw6ClC4jENSX3U         0.823   0.653  4.0    -4.378   0.0
# 7xW9kuak6ViVF8Z9Ih15ZM         0.833   0.782  7.0    -3.743   1.0
# 7xiaGjbAhXFO8bkjLyfdcN         0.773   0.748  1.0    -7.540   0.0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 00A8hsKelAI5N7bmcbvn9v       0.1030        0.1550          0.000001    0.1160
# 00BBC45AUahDMdYaJ6wjxp       0.1690        0.2470          0.000000    0.0616
# 00v3qhEMB8Z8D5PU2LpDFK       0.1590        0.1210          0.006310    0.0562
# 01NRErhQZIau5ebhdXMhGs       0.2300        0.2220          0.000000    0.2570
# 01NjsQ8VVcaPNZPIfzhhb1       0.0680        0.1590          0.000000    0.1450
# ...                             ...           ...               ...       ...
# 7vS7knISRY4QEk6vzeOGk3       0.0590        0.0995          0.000419    0.2010
# 7vy0S9WfaUoC4SZE6DO65M       0.2790        0.0931          0.000000    0.1180
# 7xMICFkbPw6ClC4jENSX3U       0.0402        0.0531          0.000080    0.0904
# 7xW9kuak6ViVF8Z9Ih15ZM       0.2810        0.0869          0.000000    0.1100
# 7xiaGjbAhXFO8bkjLyfdcN       0.2570        0.0443          0.000483    0.0677
#
#                         valence    tempo            type  \
# 00A8hsKelAI5N7bmcbvn9v    0.962  105.964  audio_features
# 00BBC45AUahDMdYaJ6wjxp    0.905  159.986  audio_features
# 00v3qhEMB8Z8D5PU2LpDFK    0.766  146.949  audio_features
# 01NRErhQZIau5ebhdXMhGs    0.537  105.075  audio_features
# 01NjsQ8VVcaPNZPIfzhhb1    0.361  106.052  audio_features
# ...                         ...      ...             ...
# 7vS7knISRY4QEk6vzeOGk3    0.851  130.017  audio_features
# 7vy0S9WfaUoC4SZE6DO65M    0.811  113.931  audio_features
# 7xMICFkbPw6ClC4jENSX3U    0.588  100.023  audio_features
# 7xW9kuak6ViVF8Z9Ih15ZM    0.820  157.037  audio_features
# 7xiaGjbAhXFO8bkjLyfdcN    0.511  157.874  audio_features
#
#                                             id  \
# 00A8hsKelAI5N7bmcbvn9v  00A8hsKelAI5N7bmcbvn9v
# 00BBC45AUahDMdYaJ6wjxp  00BBC45AUahDMdYaJ6wjxp
# 00v3qhEMB8Z8D5PU2LpDFK  00v3qhEMB8Z8D5PU2LpDFK
# 01NRErhQZIau5ebhdXMhGs  01NRErhQZIau5ebhdXMhGs
# 01NjsQ8VVcaPNZPIfzhhb1  01NjsQ8VVcaPNZPIfzhhb1
# ...                                        ...
# 7vS7knISRY4QEk6vzeOGk3  7vS7knISRY4QEk6vzeOGk3
# 7vy0S9WfaUoC4SZE6DO65M  7vy0S9WfaUoC4SZE6DO65M
# 7xMICFkbPw6ClC4jENSX3U  7xMICFkbPw6ClC4jENSX3U
# 7xW9kuak6ViVF8Z9Ih15ZM  7xW9kuak6ViVF8Z9Ih15ZM
# 7xiaGjbAhXFO8bkjLyfdcN  7xiaGjbAhXFO8bkjLyfdcN
#
#                                                          uri  \
# 00A8hsKelAI5N7bmcbvn9v  spotify:track:00A8hsKelAI5N7bmcbvn9v
# 00BBC45AUahDMdYaJ6wjxp  spotify:track:00BBC45AUahDMdYaJ6wjxp
# 00v3qhEMB8Z8D5PU2LpDFK  spotify:track:00v3qhEMB8Z8D5PU2LpDFK
# 01NRErhQZIau5ebhdXMhGs  spotify:track:01NRErhQZIau5ebhdXMhGs
# 01NjsQ8VVcaPNZPIfzhhb1  spotify:track:01NjsQ8VVcaPNZPIfzhhb1
# ...                                                      ...
# 7vS7knISRY4QEk6vzeOGk3  spotify:track:7vS7knISRY4QEk6vzeOGk3
# 7vy0S9WfaUoC4SZE6DO65M  spotify:track:7vy0S9WfaUoC4SZE6DO65M
# 7xMICFkbPw6ClC4jENSX3U  spotify:track:7xMICFkbPw6ClC4jENSX3U
# 7xW9kuak6ViVF8Z9Ih15ZM  spotify:track:7xW9kuak6ViVF8Z9Ih15ZM
# 7xiaGjbAhXFO8bkjLyfdcN  spotify:track:7xiaGjbAhXFO8bkjLyfdcN
#
#                                                                track_href  \
# 00A8hsKelAI5N7bmcbvn9v  https://api.spotify.com/v1/tracks/00A8hsKelAI5...
# 00BBC45AUahDMdYaJ6wjxp  https://api.spotify.com/v1/tracks/00BBC45AUahD...
# 00v3qhEMB8Z8D5PU2LpDFK  https://api.spotify.com/v1/tracks/00v3qhEMB8Z8...
# 01NRErhQZIau5ebhdXMhGs  https://api.spotify.com/v1/tracks/01NRErhQZIau...
# 01NjsQ8VVcaPNZPIfzhhb1  https://api.spotify.com/v1/tracks/01NjsQ8VVcaP...
# ...                                                                   ...
# 7vS7knISRY4QEk6vzeOGk3  https://api.spotify.com/v1/tracks/7vS7knISRY4Q...
# 7vy0S9WfaUoC4SZE6DO65M  https://api.spotify.com/v1/tracks/7vy0S9WfaUoC...
# 7xMICFkbPw6ClC4jENSX3U  https://api.spotify.com/v1/tracks/7xMICFkbPw6C...
# 7xW9kuak6ViVF8Z9Ih15ZM  https://api.spotify.com/v1/tracks/7xW9kuak6ViV...
# 7xiaGjbAhXFO8bkjLyfdcN  https://api.spotify.com/v1/tracks/7xiaGjbAhXFO...
#
#                                                              analysis_url  \
# 00A8hsKelAI5N7bmcbvn9v  https://api.spotify.com/v1/audio-analysis/00A8...
# 00BBC45AUahDMdYaJ6wjxp  https://api.spotify.com/v1/audio-analysis/00BB...
# 00v3qhEMB8Z8D5PU2LpDFK  https://api.spotify.com/v1/audio-analysis/00v3...
# 01NRErhQZIau5ebhdXMhGs  https://api.spotify.com/v1/audio-analysis/01NR...
# 01NjsQ8VVcaPNZPIfzhhb1  https://api.spotify.com/v1/audio-analysis/01Nj...
# ...                                                                   ...
# 7vS7knISRY4QEk6vzeOGk3  https://api.spotify.com/v1/audio-analysis/7vS7...
# 7vy0S9WfaUoC4SZE6DO65M  https://api.spotify.com/v1/audio-analysis/7vy0...
# 7xMICFkbPw6ClC4jENSX3U  https://api.spotify.com/v1/audio-analysis/7xMI...
# 7xW9kuak6ViVF8Z9Ih15ZM  https://api.spotify.com/v1/audio-analysis/7xW9...
# 7xiaGjbAhXFO8bkjLyfdcN  https://api.spotify.com/v1/audio-analysis/7xia...
#
#                         duration_ms  time_signature
# 00A8hsKelAI5N7bmcbvn9v     183541.0             4.0
# 00BBC45AUahDMdYaJ6wjxp     193106.0             4.0
# 00v3qhEMB8Z8D5PU2LpDFK     122000.0             4.0
# 01NRErhQZIau5ebhdXMhGs     141714.0             4.0
# 01NjsQ8VVcaPNZPIfzhhb1     174008.0             4.0
# ...                             ...             ...
# 7vS7knISRY4QEk6vzeOGk3     245701.0             4.0
# 7vy0S9WfaUoC4SZE6DO65M     136385.0             4.0
# 7xMICFkbPw6ClC4jENSX3U     174405.0             4.0
# 7xW9kuak6ViVF8Z9Ih15ZM     159048.0             4.0
# 7xiaGjbAhXFO8bkjLyfdcN     124683.0             4.0
#
# [1758 rows x 27 columns]

# %%
full_df_.to_csv('soca_working.csv')

# %% [markdown]
# # API Calls from artist

# %%
artists = ['barrington levy','beres hammond','gregory isaacs','wayne smith', 
'administrators','barry boom','aswad','beshara','carol gonzales','carol thompson',
'cassandra','the chosen few','dean fraser','delroy wilson','derrick harriot',
'derrick hara','donna rhoden','errol dunkley','the investigators','janet kay','jean adebambo',
'johnny osborne','joy mack','junior english','louisa mark','mari pierre','melina carole',
'mighty diamonds','mike anthony','otis gayle''paulette tajah','peter hunningale',
'peter sence','portia morgan','roger robin','ruddy thomas','sadonians','ting stewart',
'trevor walters','tt ross','vivan jones','Aaron neville','Abbasynians','Administrators',
'Albians','Anthony David','Anthony Hamilton','Anthony Rich','Arema','Aswad','B B Seaton',
'Barrington Spence','Barry Biggs','Barry Boom ','Beres Hammond','Beshara','Bitty McleaL',
'Bitty McLean','Black Harmony','Bob Andy','Bobbie Houston','Bobby Melody','Boris Gardiner',
'Brian & Tony Gold','Brown Sugar','Bunny Maloney','Carlene Davis','Carol Campbell',
'Carol Catlin','Carol Gonzales','Carol Thompson','Carroll Thompson','Cassandra','cassandra',
'Chantells','Charisma','China Black','Chosen Few','Chosen Ones','Claudia Fontaine','Cool Notes',
'Cynthia Schloss','David Miller','Dean Fraiser','Deborahe Glasgow','Dee Sharp','Delroy Wilson ',
'Delroy Wilson','Dennis Brown','Dennis Brown & Gregory Isaacs','Dennis Brown & Janet Kay ',
'Derrick Harriot','Derrick Lara','Don Campbell','Don Carlos','Don Ricardo','Donna Rhoden',
'Donna Rohden','Eargasm','Errol Dunkley','Family Love','Freddie McGregor','Heptic','The Heptones',
'In Crowd','The Investigators','Janet Kay','Janet Lee Davis','Jean Adebambo','Jimmy London',
'john mc clean','johnny osborne','Joy Mack','Judy Boucher','Junior Byles','Junior English',
'Keith Barrow','Keith Douglas','Kofi','Lloyd Brown','Lorraine','Louisa Marks','love & unity',
'Love & Unity','Luciano','Mad Cobra','Maria Hague','Maria Taylor','Marie Pierre','Matumbi',
'Maxi Priest','Maxi Priest & Beres Hammond','Melanie Fiona','Melina Carole','Mighty Diamonds',
'Mike Anthony','Natural Ites','Natural Touch','One Blood','Otis Gayle','Outer Limits','Pam Hall',
'Panchita','Paul Dawkins','Paula','Paulette Tajah','Peter Hunningale','Peter Sence','Phill',
'Portia Morgan','Prediction','Raymond Fontaine ','Renee Geyer','Ricardo Mckenzie','Richie Davis',
'Riot Squad','Roger Robin','Roland & Caroline','Rolands','Ruddy Thomas','Ruddy Thomas & Trinity',
'Sacfrice','Sadonians','Sammy Levi','Sanchez','Sandra Cross','Sandra Reid','Simplicity',
'Storm','Sylvia Tella','Ting Stewart','Trevor Walters','Triston Palmer','TT Ross',
'Victor Romero Evans','Vivan Jones','Winston Reedy','Zuruchi',
]

# %%
df = api.get_artists_uri(artists)
df

# %%
a = list(df['uri'])
a

# %%
def get_tracks_from_artist(lst):
    
    for artist in lst:
        r = requests.get(f"https://api.spotify.com/v1/artists/{artist}/top-tracks?country=US",
                     headers={ "Accept": "application/json", "Content-Type": "application/json", "Authorization": 
                              get_auth()})

        data =r.json()
        
    return data
        
#     track = []

#     for x in range(0, 10):
#         if (len(data['tracks'][x] > 0)):
#             track.append({
#                 'id' : data['tracks'][x]['id'],
#                 'name' : data['tracks'][x]['name']
#                 })

#     return track

# %%
data = get_tracks_from_artist(a)

# %%
data['tracks'][0]

# %%
r = requests.get(f"https://api.spotify.com/v1/artists/57ALvbCBaCkNlgTOSiUPdT/top-tracks?country=US",
                 headers={ "Accept": "application/json", "Content-Type": "application/json", "Authorization": 
                          get_auth()})

data =r.json()

# %%
full[0]['artists']['items'][0]['uri']

# %%
success = []

for x in range(len(artists)):

    try:
        full[x]['artists']['items'][0]['name'].lower() == artists[x].lower()
    except:
        continue
    else: 
        success.append(artists[x])

# %%
success

# %%
full[1]

# %%
if full[2]

# %%
dets = []

for artist in artists:
    results = sp.search(q=artist, type='artist', limit=None)
    
    results.status_code == requests.codes.ok
    
    dets.append({'name' : results['artists']['items'][0]['name'],
                 'uri' : results['artists']['items'][0]['uri']
                })
dets  

results

#

# %%
import numpy as np

# %%
txtt = pd.read_table('Lovers.txt', engine='python')
artists = txtt['Artist'].unique()
artists = artists.tolist()
artists

# %%
dets = []

for artist in artists:
    results = sp.search(q=artist, type='artist', limit=None)


results['artists']['items'][0]['name'] == artists[0]
#     dets.append({'name' : results['artists']['items'][0]['uri'],
#                  'uri' : results['artists']['items'][0]['name']
#                 })
# dets    

# resp.status_code == requests.codes.ok

# %%
for x in len(artists):
    results['artists']['items'][1]['name'] == artists[x]

# %%
results

# %%
results = sp.search(q='vybz kartel', limit=None)

track_name = []
track_artist = []
track_uri = []
track_duration = []
track_explicit = []

    
for x,y in enumerate(results['tracks']['items']):
    uri = results['tracks']['items'][x]['uri']
    track_name = results['tracks']['items'][x]['name']
    duration = results['tracks']['items'][x]['duration_ms']
    explicit = results['tracks']['items'][x]['explicit']
    artist = results['tracks']['items'][x]['artists'][0]['name']  

    dic = {
        'uri' : uri,
        'artist' : artist,
        'track' :track_name,
        'duration' : duration,
        'explicit' : explicit,
    }
    
results

# %%
df.iloc[:,:5]

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='', client_secret='')

export SPOTIPY_CLIENT_ID='472d9fe420af4222b7afdd11b9578446'
export SPOTIPY_CLIENT_SECRET='518bc9207d064855be7f6300ca080c76'
export SPOTIPY_REDIRECT_URI='your-app-redirect-url'

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
playlists = sp.user_playlists(username)

# %%
playlists
user = 'loliblews?si=boPlbahBRjWMOvfb8dw95g'

# %%
artists_edit.append(re.sub('\s+', '%20', artist))
        
    full = []

# %% [markdown]
# # Non-Reggae

# %%
r = requests.get("https://api.spotify.com/v1/browse/featured-playlists?country=gb&timestamp=2019-06-01T00%3A00%3A00&limit=50&offset=0",
             headers={ "Accept": "application/json", "Content-Type": "application/json", "Authorization": 
                      oath})

data =r.json()

# %%
data['playlists']['items'][0]['uri']
# Out:
# 'spotify:playlist:37i9dQZF1DX0MXH7aN4Pxn'

# %%
random_playlists = []

for x in range(0,9):
    random_playlists.append(data['playlists']['items'][x]['uri'])
    
random_playlists
# Out:
# ['spotify:playlist:37i9dQZF1DX0MXH7aN4Pxn',
#  'spotify:playlist:37i9dQZF1DWWCAjkSJsi1g',
#  'spotify:playlist:37i9dQZF1DX4W3aJJYCDfV',
#  'spotify:playlist:37i9dQZF1DWSvfPiFfb8Mi',
#  'spotify:playlist:37i9dQZF1DX4v0Y84QklHD',
#  'spotify:playlist:37i9dQZF1DXa71eg5j9dKZ',
#  'spotify:playlist:37i9dQZF1DX30w0JtSIv4j',
#  'spotify:playlist:37i9dQZF1DX1jlzMTQ2PY5',
#  'spotify:playlist:37i9dQZF1DXdc0DUqaW3MZ']

# %%
plays = []

for x in range(len(random_playlists)):
     plays.append(random_playlists[x][-22:])

# %%
plays
# Out:
# ['37i9dQZF1DX0MXH7aN4Pxn',
#  '37i9dQZF1DWWCAjkSJsi1g',
#  '37i9dQZF1DX4W3aJJYCDfV',
#  '37i9dQZF1DWSvfPiFfb8Mi',
#  '37i9dQZF1DX4v0Y84QklHD',
#  '37i9dQZF1DXa71eg5j9dKZ',
#  '37i9dQZF1DX30w0JtSIv4j',
#  '37i9dQZF1DX1jlzMTQ2PY5',
#  '37i9dQZF1DXdc0DUqaW3MZ']

# %%
random_df = get_tracks_from_playlist(plays)

# %%
random_df[0]['']
# Out:
# {'added_at': '2020-01-10T16:16:05Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MIVXf74SZHmTIp4V4paH4'},
#      'href': 'https://api.spotify.com/v1/artists/1MIVXf74SZHmTIp4V4paH4',
#      'id': '1MIVXf74SZHmTIp4V4paH4',
#      'name': 'Mabel',
#      'type': 'artist',
#      'uri': 'spotify:artist:1MIVXf74SZHmTIp4V4paH4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0o9d312clt8gVtz1uZZkBW'},
#    'href': 'https://api.spotify.com/v1/albums/0o9d312clt8gVtz1uZZkBW',
#    'id': '0o9d312clt8gVtz1uZZkBW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/418e4891cba17320219be65a7fb4fc59eef61157',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/bc5dfe03a297bd51072feecfe2f09e25d583db93',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/c615945f5ba1ea717822fa258aca16fe9c4bfaf7',
#      'width': 64}],
#    'name': 'Mad Love (Remixes)',
#    'release_date': '2019-07-05',
#    'release_date_precision': 'day',
#    'total_tracks': 3,
#    'type': 'album',
#    'uri': 'spotify:album:0o9d312clt8gVtz1uZZkBW'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MIVXf74SZHmTIp4V4paH4'},
#     'href': 'https://api.spotify.com/v1/artists/1MIVXf74SZHmTIp4V4paH4',
#     'id': '1MIVXf74SZHmTIp4V4paH4',
#     'name': 'Mabel',
#     'type': 'artist',
#     'uri': 'spotify:artist:1MIVXf74SZHmTIp4V4paH4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0nJcDqY6ox4kHB92AuRA8j'},
#     'href': 'https://api.spotify.com/v1/artists/0nJcDqY6ox4kHB92AuRA8j',
#     'id': '0nJcDqY6ox4kHB92AuRA8j',
#     'name': 'Blinkie',
#     'type': 'artist',
#     'uri': 'spotify:artist:0nJcDqY6ox4kHB92AuRA8j'}],
#   'available_markets': ['AD',
#    'AE',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'SA',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 200893,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71903154'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5qiQbOa6AFEO3P111y9Jry'},
#   'href': 'https://api.spotify.com/v1/tracks/5qiQbOa6AFEO3P111y9Jry',
#   'id': '5qiQbOa6AFEO3P111y9Jry',
#   'is_local': False,
#   'name': 'Mad Love - Blinkie Remix',
#   'popularity': 62,
#   'preview_url': None,
#   'track': True,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:5qiQbOa6AFEO3P111y9Jry'},
#  'video_thumbnail': {'url': None}}

# %%
ply = []
trk = []
tracks = []
# uri = []

for x in range(len(random_df)):
    ply.append(random_df[x]['track'])
    
for i in range(len(ply)):
    if ply[i] == None:
        continue
    else:
        trk.append(ply[i]['uri'])
        tracks.append({
            "track_name" : ply[i]['name'], 
            "artist" : ply[i]['artists'][0]['name'],
            "album" : ply[i]['album']['name'], 
            "release_date" : ply[i]['album']['release_date'],
            "explicit" : ply[i]['explicit'], 
            "track_id" : ply[i]['id'],
            "track_uri" : ply[i]['uri']
        })

# %%
track = pd.DataFrame(tracks)

# %%
track
# Out:
#                               track_name         artist  \
# 0               Mad Love - Blinkie Remix          Mabel
# 1                                  Sorry     Joel Corry
# 2             Bruises - Steve Void Remix  Lewis Capaldi
# 3    Wish You Well - Benny Benassi Remix         Sigala
# 4                              About You      Papa Zeus
# ..                                   ...            ...
# 610                        See Man Smile   Murkage Dave
# 611                           Monochrome            AMA
# 612                         Talk in Code   Hannah Lucia
# 613                           The Middle          Monro
# 614                   Can't Show My Face         TENDER
#
#                                album release_date  explicit  \
# 0                 Mad Love (Remixes)   2019-07-05     False
# 1                              Sorry   2019-04-05     False
# 2                         Bruises EP   2019-09-27     False
# 3            Wish You Well (Remixes)   2019-07-05     False
# 4                          About You   2019-07-26     False
# ..                               ...          ...       ...
# 610     Murkage Dave Changed My Life   2018-10-19     False
# 611                       Monochrome   2018-11-22     False
# 612                     Talk in Code   2019-04-19     False
# 613                         Deep End   2018-12-05      True
# 614  Bottled Up / Can't Show My Face   2018-12-07     False
#
#                    track_id                             track_uri
# 0    5qiQbOa6AFEO3P111y9Jry  spotify:track:5qiQbOa6AFEO3P111y9Jry
# 1    23Q3zB4aIt4vvGknhBSE7O  spotify:track:23Q3zB4aIt4vvGknhBSE7O
# 2    4raMIjIjMc8JohHth7l9lG  spotify:track:4raMIjIjMc8JohHth7l9lG
# 3    49jQjsgh1bqjLW1UXGPIj2  spotify:track:49jQjsgh1bqjLW1UXGPIj2
# 4    2dzmO8gQgQQBFchqng9MKx  spotify:track:2dzmO8gQgQQBFchqng9MKx
# ..                      ...                                   ...
# 610  1qIOc7ciawp9BoIy0S4a81  spotify:track:1qIOc7ciawp9BoIy0S4a81
# 611  5oHjw5NRUOyxwM34rs8ROv  spotify:track:5oHjw5NRUOyxwM34rs8ROv
# 612  5MaftJhkfPQEN1jYbkCYC1  spotify:track:5MaftJhkfPQEN1jYbkCYC1
# 613  2THYSdShsssHT5RBvgHrjm  spotify:track:2THYSdShsssHT5RBvgHrjm
# 614  2rwxsA3kNJj8ycasZGU1DS  spotify:track:2rwxsA3kNJj8ycasZGU1DS
#
# [615 rows x 7 columns]

# %%
trk__ = []

for x in range(len(trk)):
     trk__.append(trk[x][-22:])

# %%
trk__
# Out:
# ['5qiQbOa6AFEO3P111y9Jry',
#  '23Q3zB4aIt4vvGknhBSE7O',
#  '4raMIjIjMc8JohHth7l9lG',
#  '49jQjsgh1bqjLW1UXGPIj2',
#  '2dzmO8gQgQQBFchqng9MKx',
#  '5fOJe6vJ3vJXMrN6v362WJ',
#  '4s4zrXirxpmFK0oanVjWBV',
#  '6qLkMLUIkdtX34gHF9sPFL',
#  '03druhrRJ5f3MJYg38NF2c',
#  '4EJI2XGViSQp6WscLKgYDD',
#  '5aYWnrsYvJk8NT7PmUcxVN',
#  '0GiwV6v3AgJfdu59tj719Y',
#  '2NBgfdrHa281oTjYQtublb',
#  '6fenHIxXuuzKB55wY4WCHP',
#  '4WEbQze78TsPiJwJVsKD34',
#  '1Ei4I19L2hnsMQYAlaqQLM',
#  '7CHi4DtfK4heMlQaudCuHK',
#  '2lPSvn7iahl7I2L4HVtF0N',
#  '5FQUb9sBnjA2Cd0lujJ3hr',
#  '5OPutqODUjt2Y8fdBYTGH0',
#  '4u7Fvnd5xJW1HYXOwvE5Wr',
#  '1ztOeR0UMNFGj6B6b1sAi4',
#  '0qaWEvPkts34WF68r8Dzx9',
#  '0X0jMAZeR8xSlghtq5s4Ol',
#  '2r4mpuIYFgKsjeykJTQMqX',
#  '56SkLjnwBXnAkHSf6jBPk3',
#  '6nRNYQiLt3RU06fzHxCnsc',
#  '1SG6r7daFfpzPcU15luVqB',
#  '4UIUaKFABiomFavFdKOwMb',
#  '2UkF0EWfh0T90ScJzGqnD1',
#  '2c0oLbC058vGMb89pAJ9EZ',
#  '3hRCtSyFLhWsuSQsT0a8TL',
#  '2tnVG71enUj33Ic2nFN6kZ',
#  '4tjiMso6FJp1FTlZKOaqqX',
#  '3t2Cyq3GntNxnffzRRlCLp',
#  '43XVdVydjpHCCGMrsjc785',
#  '7CN6ZYIX338ekn7pb2CpQp',
#  '4QUA94c3ycZm8dnpPih4sf',
#  '6LCsZ8ARrIq0n9nr6gM2ru',
#  '6bXi3POdPDmcJJ2A43pLIw',
#  '54CEeDq1YRLtPOvVsNbxbF',
#  '1By1ldFnEnvZI47HEeTHk5',
#  '1DV5T7iCGaC6D39aNDdxTv',
#  '7b4ky1LlQLFhXHmhZkFgqV',
#  '0IhTEIjFaRt3B2NQYf9azQ',
#  '40YHYSTnIo0l6Z5Nvti9xl',
#  '2nbmXP1GTWZO5KvhVV8hZv',
#  '5wBZLsoQtQcYRCo3qGaYWF',
#  '7DC0O3pMpDFefdk51dr7pU',
#  '762vNiCFtKfWLdnalxefgI',
#  '4PCcZteFHyza67zAZ3GuMd',
#  '1IqANTbvKLojRoomq685LA',
#  '2xUjNGHjJOBcpTf7dYx4EY',
#  '56UNoQz1kXeBZeqmQbFpYe',
#  '4Mnw05kNd0j1XDHwtfzofp',
#  '0dAn58pe2GWDTlqa2Th4mP',
#  '7cVZP5NpfJswuCO3kvX4zd',
#  '2M5BecF1hOqHevr4BDRi84',
#  '4todOcpbt1Kpp4jl5x0r9h',
#  '1KGi9sZVMeszgZOWivFpxs',
#  '0BzapQ62bPrdKS8sGVQ7UF',
#  '0VqSg7nsmUNJKHZYufNZFo',
#  '49hFJr1GCLuf0d7zeyyjIJ',
#  '1BPybPVkDfUjFDvqG04l58',
#  '77jaOS5YDCDGPto5Pomi4h',
#  '1NOdN5Qoz4GGsVETMHqsMb',
#  '7H6ev70Weq6DdpZyyTmUXk',
#  '1ElsvWNXbo3jXs4OuakQLn',
#  '3IFVskDtdJTwAZ0I8HGvoO',
#  '3NnUocBmP4PuEEe1eQkuwE',
#  '6HfooVSTxGJAMSl2KMrmCV',
#  '0gPQTLaqHDgdupKEok7J2x',
#  '2pRyjmTGkz5i8xemOtJ7pG',
#  '4P5Rntc1SI0IGeqlrWJQCq',
#  '5hyKiDwqUgI57ONsZcGh4z',
#  '2QsZVnbWVSjKMXK6K3uRBL',
#  '5q1hpdlf8ncJUhKLyjHoHB',
#  '6J3LHclKrdg1zLArH3kmF4',
#  '023lag1AgeOf7YChojecRu',
#  '7lVEI0S5Kad3KTWn4A2QvX',
#  '3stQUVyIkVtY7KbU8OGnEN',
#  '0nknDCcG0tZQuoVpRL7Bfj',
#  '5xV0Czdqefft6sPDqjmFBu',
#  '40FFyvBiecWpeKjXHgCRsr',
#  '3U3Ff8ZvL6oEu1r98gCCWW',
#  '3J4YoloryJCieZ9kapS1oL',
#  '7JKEA8xYDoFp4q0QBW2PGg',
#  '2yRYI0OVKjfHm1586P0BJO',
#  '7pxudg8pAyUxh9wm87qBxR',
#  '3QHPHLAkYV5cQBUYs6rowx',
#  '2mKouqwAIdQnMP43zxR89r',
#  '0iFOG4Ki9aDmJUYUFHQlPG',
#  '29TJpH7vOyURlvEVVTMXwq',
#  '0tHr952isDUWtoYBa68RUb',
#  '0aj2QKJvz6CePykmlTApiD',
#  '5bPvKo7mH5ZETLSbdP1oHo',
#  '3nOMGGeQppHhfrkQ65VLVQ',
#  '6zMUIb4uce1CzpbjR3vMdN',
#  '3jDdpx9PMlfMBS5tOBHFm9',
#  '18vdhCWxqPohnPwicDi3Xr',
#  '7k6IzwMGpxnRghE7YosnXT',
#  '4INDiWSKvqSKDEu7mh8HFz',
#  '5dWfl2PBpKHpBVdz95wxK1',
#  '7LIKB7mzky7NjDUlag95Fu',
#  '1bmnlM7k7q1E8kO4SSrZBn',
#  '68vgtRHr7iZHpzGpon6Jlo',
#  '0AvV49z4EPz5ocYN7eKGAK',
#  '0kvKNrIyDP9ScCw2Jo16bK',
#  '2lvbX38f7BFP8AIWB9VyRu',
#  '0uEp9E98JB5awlA084uaIg',
#  '0vYMzeTmfbnrAhGPRcJqVP',
#  '5PMKzsUsTpZZGsCcJBuhP2',
#  '5hALSggfcyvBNLUHY8pvZd',
#  '4pmc2AxSEq6g7hPVlJCPyP',
#  '0I3q5fE6wg7LIfHGngUTnV',
#  '59OZXaIPW4QHMmJcoSZYpC',
#  '7bVeIwMoakhx9SzB0NMn98',
#  '6sHsXIJoEN5JpdkGMQDJxt',
#  '4CweuuMMzi71pO0MSRgyaT',
#  '6pWzCKTrKrwbUPzY8RLCoP',
#  '5TxdQaqp2Xn9IBTlfq26l7',
#  '5x2TDyeeTpf0riUoQDrvsV',
#  '31CsLSgn0HdZEVC8Bnnmvr',
#  '7qvjI9Mo0KQTGz6NB0ZLYQ',
#  '2DyzYki95bDbkVNczAcQtz',
#  '5J7iGuzi7Nj8SGvt0TAVzK',
#  '5mNV8Mz59bzyuQ53gTw0c0',
#  '0BBOLOV5JntPL3341swIre',
#  '1bJbhVv617ihj4WoMxtTJX',
#  '6Wt5QBzHp9vdSLAFlvdnDQ',
#  '1X3T1YVWuYjjzXL5LkfwcE',
#  '0ORQ2L5bsBcGH9a5mJp1DX',
#  '4Tf94tAHtlQxjbeeyU3y7C',
#  '5FLctoy4mpCxLJ1QPneTOV',
#  '7oPnZNl1acGA7ELxsNirrR',
#  '7jUhvpXow0mD27v77F6vC2',
#  '7lVNTXkI3cHFvcXiI8damb',
#  '7KwZNVEaqikRSBSpyhXK2j',
#  '0lQk3EUb2YTXs1xVmDiOQm',
#  '3gM8jkNVAeZax2boZhMhcx',
#  '280GUUkqaTBa12SCpQdlip',
#  '59ZTxQo8rBycIXPLUIKvE2',
#  '2w9Nu1hgsBRlcgiRGXucgA',
#  '1dHLyXaqQDLxH4IyZ3NgdN',
#  '0k2GOhqsrxDTAbFFSdNJjT',
#  '7cUhxtLxcNZXV6Qdpi8PTO',
#  '3vZO25GdYuqFrR1kzZADnp',
#  '2Untv3x8MyoAcpF9DwMy7Z',
#  '4789yoeBIsBi6et3z0fyly',
#  '2xEjC3OfiWOjYlnV9Vonxp',
#  '7HMmFQsKsljwTw8bS7lu19',
#  '0NoA5UyGQSF52p5IYBNlXA',
#  '1bObrsJGW0UCIGZkvnDqbe',
#  '1ToprX3cpBiXoAe5eNSk74',
#  '6V8IY1khSjXlgvG6mbIyXQ',
#  '3oIVK7arAFuUOCGafPLxSC',
#  '5yY9lUy8nbvjM1Uyo1Uqoc',
#  '2V6dyeFrTmIrdXFoMcZHO9',
#  '2usxQITOSDqvkYiI0oIwao',
#  '5XrQJMPNtX20OFyWn6RuWg',
#  '3Kq7kKBwHPOvdmyZanK4AP',
#  '5X8FVIy9iaXoDEiIlCjcmp',
#  '1b3nlcP6hogIzYRVK2Ui7K',
#  '3idB0OhcBXrnIgOoV3W4q4',
#  '0HhleUCwCfFYS413WmpMxJ',
#  '0EdgK7ASb4kfRkW8pVMN02',
#  '3eoNUm0LU9hATVVi9w4fM6',
#  '11wzBoHOY1WJmIPQVBavGe',
#  '57XM1QkO2zyCgcybsYd9Cj',
#  '61ZM92T2zaXIVsqncThQzC',
#  '0YoquWDxpwAq8jFPj3K8wp',
#  '6u2sNdU0FNLbtZypNb2ubE',
#  '6TYlDTa9AQDvjqwbxlvFyI',
#  '1g8u7Bh6uv8KMPlgBj95nQ',
#  '1aQqtnz30d2vAG54XFNpu0',
#  '0HfDFpIlcq3aG2XMVUEbLz',
#  '0PQsrLxPbOBBwwmXCnGvcF',
#  '5yeSWsJ0E76OvvUoOWIyIF',
#  '3ClBKQkKoaUQ6UOhe2xlJK',
#  '11OwAR3GlBj9E35Cznf7Lj',
#  '3kKtliJFrZ5wv7OzyvK5AC',
#  '0fH1Vujo6WEiWao3gEWxew',
#  '0EJYTUfDCEq4wyaQlDcn7T',
#  '2FCpAv6bvo6bLK0XW6sgeE',
#  '6lbDbnp7JP728qEeMd26Ca',
#  '2OtnmFipsJgxUPkwnMP11I',
#  '6qQ8a6M6o5mfj9wTdrbSgG',
#  '6nl32vTZsMv23myzbRSAea',
#  '4wM2x3pCDlRAxVAXPATEip',
#  '5dvxDUiT7sEEpJf9gVBU0g',
#  '6kckNpuM5oXZrObLExRg6d',
#  '7wkKPIBtnWwXpQxDXFSmQO',
#  '4vFicRRBJFCC5UofT5sWAT',
#  '6DC6pQrMENEDcQ8HPdQlx0',
#  '74HK5xdyRLyvl278Qp31pe',
#  '3FGiFUJRRp5RGikVrs6kig',
#  '3Yx6JaMc354G1kCevszZ1z',
#  '4VgYtXCVJ7IbWAZ5ryfvEQ',
#  '15CfptpFnwDrhkWt8JPyfN',
#  '0Pqix0NTfbuROfPbaZbBgp',
#  '73S02IpUBcuAeAM1jTS8dk',
#  '1hUmqRBZpseNjByPAEW6AJ',
#  '1iB9grDyfaBWMnyePLCQqY',
#  '2lGP9qlQomGTxxUSAPP3JJ',
#  '3Cs9Qiuge7RpWcpMXVBA5M',
#  '4M2DrKXtoQ9JjTrMfeImoc',
#  '3eq83AsxUcnYS9k57MoBbE',
#  '7qH8IrxrNK09nGBJ0M8Yt2',
#  '0VmlHv7G5VNISmPKzx55Ba',
#  '7eSshDBZm9DIg3RaYARf8e',
#  '1GYprorbYJk9QWBIYSsbnb',
#  '0IbKDougbWSz6DUAixncoB',
#  '7G4JtFBBuMEjDKJLOB4xA7',
#  '3CFzETSNTZKAyC2jHQ8Ero',
#  '2q7kfK2s7o9L6UXY857PDc',
#  '5jiJXFYMQpBfPr4N1Z46oI',
#  '7yXTncV8g2PZVImMR5m5Td',
#  '5rzhQNi9lg1Hhyew5ifUGu',
#  '49KpQCADAIEfKnmNa6QUXm',
#  '0jh5NRR4gX9tsFMLFDhEmX',
#  '1Ia95g66IhlAJ3qVI4qI8W',
#  '6eEYGGFfFbtKHCgJM4uh9v',
#  '58HvfVOeJY7lUuCqF0m3ly',
#  '3glRVTeqKmtGqmblN77lw0',
#  '2RFJDwxJa0lhtbLd71iOWC',
#  '44REeXBIh1ho0YjyM52xHO',
#  '3wM13F78fqqDXxJdBPO96S',
#  '7oTqDba8VGNiqwPreAxM8H',
#  '2CiOFdudXTfZfsd1lZqrhR',
#  '0UXqqOq4p6ycJXBBrOLjJ9',
#  '5RKWEhfFeV1Ly33ZFtIst0',
#  '2LqAEimH89IoYqTkDc1Fo3',
#  '5vhNn6ZfEXbFMw0qR6Grpn',
#  '2u00CbgIyWfkiLrYgW8IK6',
#  '5dVoFQZwySXrBDd3AszUIe',
#  '4xO71bjbkDvOUtIcE169oX',
#  '1jAmIJHFuBsTIoUqtUHU27',
#  '3zF3pigJ8LTQQtjsYrDmUI',
#  '0y7OfSu7FZSJViYvRKigzl',
#  '5kKGJym6i9cQJhUiELMfqI',
#  '4TmY3pycMlMkrJdXJ2lj8W',
#  '1rIPNuXlthhSUphhva5d5y',
#  '3Ld6Df2I56FQqKMku8G2li',
#  '27hxOtUPvhetUhiHMXCoEQ',
#  '6hHn9EtyvsJhovCmCCaJz2',
#  '0nJGnQziRhZZXfhwbKZIvM',
#  '1LtD3HgIONgw58BPPtVDOS',
#  '0eQ1j5MBA9Ja7zvtB9uggC',
#  '5YSu7cIVCuvbOkDeckjVhL',
#  '5jYMVtyCvXmzf7phYEUywo',
#  '6KgGRmZ3zckb95XEg4Q1fF',
#  '4hP2L49EdfLUUqNMaZE1GO',
#  '4vmngJmYQGsIw8cwZ1J41G',
#  '2ON3wXwOHtZxN6dkpBZa6f',
#  '4UACOokrBAawfs584AMmW2',
#  '35G6DJGmimKwIVhr6xeCLb',
#  '43dAjx7BOWa0v76Hx9VeG1',
#  '2vHpvjpGvISOnDrhls2wd4',
#  '3dxdD7raxoeDwMYEuL5zjD',
#  '5QgF9IMAI3CDYj1Evo8Rgx',
#  '4YTO9Z4RSkQRfCoX6kYNrz',
#  '01W03wNYeydYYX30usFAqB',
#  '5G7UKEiJ6MXpsRShpPRarl',
#  '1vJsWeFVitz10PLxpvCTOo',
#  '5tIhRlNkApQJoDA8zhOBUY',
#  '4gws52rm1wH6szEe9wX3xB',
#  '3xP4g4wokqBdvVtcRl0cwb',
#  '2RABiORxekaDV23sfNTjid',
#  '3w3LyAknbXOnyppVCI1QeW',
#  '3KmHu1gUyUk4OqWOXxQbyp',
#  '0lIUHdJO48ZjhvE2ImRiHv',
#  '40w3vYFJKrNIXJcLm447uY',
#  '35otuhTpeAQPKZOjX88OFW',
#  '6G0EEZeCqESFEjsXrldUX6',
#  '6XPa40pxRVm87X640T0WPG',
#  '1qoGrIuZEacVqDc5b1q0cS',
#  '2KnZfpgBZLGaFol55MSoAb',
#  '2vwFw8b76xQd8b0xaOVnCn',
#  '5t3oszlshIPTzpAwcCMqgw',
#  '3LF54Y7TxU5vy3YKAIfiQ4',
#  '1UxisKljksGRNwJBPp4Tri',
#  '1FSWSs9CL01RCYxXtm08Rf',
#  '6zKMARmU2Ue50cucKnIUR6',
#  '1FHNctV68GUNLgXclG2DtR',
#  '1hrsEHe39nYu1pJx0Nrxd7',
#  '5WuVWOngcRkMOx9RRLCvui',
#  '4mnTMsp8Cgf9TNiQMhH11L',
#  '2iPIMWQYcrvV6MDlnEgw4i',
#  '2lJgtPpvgs4wKY5ngX1BQ9',
#  '3yZNKN3r1USoCVij9VDSh6',
#  '4Sqc0kPuZpfI0T2TZBu8JT',
#  '0IfvvQWe8SjqiCYOMvvnwK',
#  '2sFp6E7lNBbblJGmUtCfFH',
#  '4G2CzdlKW7Ntk42eyN7hBe',
#  '4fIWvT19w9PR0VVBuPYpWA',
#  '5MONKNdpMcrynzmq5sMkB0',
#  '5pWRdriPCFhfz0JSswkdHo',
#  '04f7VdXRum3G2iIlOuWIbS',
#  '4CqpfPcxqJS2COMcA3DmNr',
#  '6SKwQghsR8AISlxhcwyA9R',
#  '1D1nixOVWOxvNfWi0UD7VX',
#  '33IQnmtJYjCcrvUUMQgi80',
#  '64JFjJB7PMlpNHkbvblNOv',
#  '3W2QKq6ks7QInnM9j4pOBt',
#  '5i9UKSttY3V7x9OnYZsMBX',
#  '1hq0Lxh8bvLp9f55cybimx',
#  '4cluDES4hQEUhmXj6TXkSo',
#  '3lkpQ3BbXxPyvwnqjipkH4',
#  '4Dm32oO01YpIubCHaAtKkN',
#  '2OsqzlVFiUGbbYwIPTKTSW',
#  '5lQfI9cYzezWGvqwrWkzqh',
#  '1hyEoJnQvkAyEJpxuOZ6C0',
#  '7oPnZNl1acGA7ELxsNirrR',
#  '483nfeDIuO67h5EjIFkFtq',
#  '4t4Uc6yNnnzBhatmarfV4Y',
#  '6LtPIXlIzPOTF8vTecYjRe',
#  '20Mf1Payc1BqR82y5zEvl0',
#  '7t0djT6xbjLPC6TttwpINp',
#  '0KpfYajJVVGgQ32Dby7e9i',
#  '5y69gQtK33qxb8a24ACkCy',
#  '63nkNgHkmfgjElTEnCzKYU',
#  '4nCpnQ1rdRIyXocx8uuC4F',
#  '3EDS89HeAhHiZKlljciK0a',
#  '6DJt4UcrXLpyOSABGnLqCI',
#  '5OXwaPptL6NFHFJj48c2QT',
#  '1A5NvsXUXc4MrXfOEojQ6p',
#  '6bHfdV6JWdB9HxBs4yqz50',
#  '1XZKOAMIDTVE1ZCjcCjwrW',
#  '00om2cgsHAwhdbpACwbAke',
#  '73IdeGI8Gt1XxcaQ6vBsyD',
#  '4vFicRRBJFCC5UofT5sWAT',
#  '7Le48y7wfWRq63dRAzVmWF',
#  '1Tzq2as6CZlNfwRoYXM5JK',
#  '7nbLUoUimkbWVQqsZ1mkp8',
#  '1MdgduELl9dV4A0Pj1VbYi',
#  '7vgiGtKJ0uHroj1iyZwXuH',
#  '0ynNGTnbdxlasLc7yZu2a8',
#  '1Due9XdQ9PAJ4wzBNtWoq2',
#  '3rCtueI7qBN2kZBZnXuk5K',
#  '3RID7FNOsH3XqUcEsgpq5v',
#  '4Go20ayHDOV10znMoy3Xy6',
#  '2OtnmFipsJgxUPkwnMP11I',
#  '4Yf9QLUM8EeHaCS7EnaHnX',
#  '6cAs4CHN3J1lR2DYeY0q2y',
#  '3oAG0POhkYYkL7XVQpeMFa',
#  '2FVhl9bRaPjAi8C4bKTQdU',
#  '2kOCDaHjAcqCDKTGsdlOsV',
#  '2jmuznDHH1QEun6UZbIeie',
#  '579xC6Zy9oF0Du0LwEsMMH',
#  '1Kuid4cjZYqgC8jmZatJEY',
#  '75QdM3nsnAluOD19G1J4il',
#  '6kTteVJEEkVs3Zges11EPO',
#  '1DiAsYHHvYhzbEX51zmT6k',
#  '7tPOBL2IEpxUtLlNlaxen7',
#  '395sAYzZTTkSZShZSvH0kb',
#  '6yWniveWfMtOksM7am2rqj',
#  '6lURqRzgfuHN5Czub5w9Px',
#  '003tJV1GB1Qtt0dZ2nDTxV',
#  '7g1viTjOfJeukhFPjv9Osf',
#  '6TNBx9lvDcqLq1GQCPNJqH',
#  '1UTlkcqSEydROgoZZKmycM',
#  '454MLi0EXJbE5A4p53cXxh',
#  '78UpOABAwxwM991JxtfCGI',
#  '0VPZL6u2bj1UNeE6o1Jm0r',
#  '2MO2eNQgv8Gdn9mmnJkh4q',
#  '4WkxkJTKEgd7Ast3fiJ0g2',
#  '04xvjRPOzA4jU6AEQyivIC',
#  '0jruXdfwQtpk4uaPYq0KVv',
#  '6NNqRs8zZJdPqBpbWCxJwD',
#  '0d3UPeSnU44wCgnIGBVwKt',
#  '2sZcltI71G4kPU50pGH50u',
#  '5MemIejVuiJJeGPaOnhUXV',
#  '5GvZeNRBzl6gtpwBpsbX2I',
#  '1wwfW6cJLS3kf0NV1dGzlA',
#  '1IDfr1mTHoI8GgLZUCYo64',
#  '5MA9jSUW11OEyO2Zya0cQz',
#  '0mLim2JIm1oezOyniz6Uue',
#  '4WSBpRmveeW5vAJAlwzCkw',
#  '68ZHty0S383k4BsvhKghlT',
#  '0VNtKhOQZConLZc1GjQckk',
#  '5YZZmmdopp9mtpehOfqc3C',
#  '2ErvhMsG9Y60kyJiYVi8zS',
#  '5shsU7FxNwV49opeudQ2Pb',
#  '5ROwuj5Lryq1BRJmaH2f5L',
#  '65TQTuti8fOntyi7NzXLTQ',
#  '2Uqi9eyX9oQPW0TSq0wo7K',
#  '10sK5as9qNJTBPs4ALbRnn',
#  '265koknSPQ5dfZFeRe4Q8Y',
#  '3evDVbXMWvTxKiePLJf6lS',
#  '6ksgZjZMCI2d4LaTmO0LXc',
#  '35IlONRZh770GBVlnU1lc9',
#  '5p0GLccbPHn3eN2IBPigg4',
#  '027LxcmuIVTqt5E2xIhRgS',
#  '6EJ3k5nWuTzFv0QjL0feiq',
#  '387t13BOBNfxBdKP7M1zVA',
#  '2gaZOlPNwT50ABukf90iS9',
#  '4yICMgapV17IPYN4bLpBAM',
#  '40m7Ext5J4Nxaky0rlXkNm',
#  '0T4JUX88SPyHnOjuL7AMtZ',
#  '48Gn9VEtPTXd8rWGf35rPA',
#  '6yLA6Tzm0JdQ5vp1piD3qF',
#  '2BJAxGByntYSadrvbSm6cI',
#  '5eFImA1OPEFC2XLhzWybcd',
#  '7t39kIigMrc10lwVfBJODK',
#  '5SsgmiLNsPRMd9KZN6TOdR',
#  '2eU63GLRBeMOszGRTCEE9E',
#  '0x7U32vZzq7e1qVpA0MBwK',
#  '6Tsu3OsuMz4KEGKbOYd6A0',
#  '0I3q5fE6wg7LIfHGngUTnV',
#  '3jagJCUbdqhDSPuxP8cAqF',
#  '20LxTsa6936zOlzTWqoPVt',
#  '3QHPHLAkYV5cQBUYs6rowx',
#  '29UzHkRHqGrqSikUDRWIam',
#  '3u9fHuAtjMY1RW2mZfO4Cf',
#  '0Zh5U48tZNeAzzLTV1CVBE',
#  '6mZcNu9i8uhOYMiEAyEx81',
#  '2NeHnSFnwNp1Z5WYgcjJ8L',
#  '7vfvZp6KZJpxiaW6rI9ieM',
#  '6MdqqkQ8sSC0WB4i8PyRuQ',
#  '1MaI6NwdrqnE3mRzOYTpoo',
#  '4RY96Asd9IefaL3X4LOLZ8',
#  '2NBQmPrOEEjA8VbeWOQGxO',
#  '2Dts49OexROL2KvCK2sokf',
#  '60WcXjimfbhk6T0gj1Eufg',
#  '3xX9hoGEq1EuMGWZl8LQL1',
#  '70FCugJxa7XW04Np6iYJdI',
#  '2eOuL8KesslTLQERQPu11D',
#  '4EOpol0K5u620R2OLfoJ1B',
#  '2oTDOIAdsxPTE7yAp4YOcv',
#  '4OjblmIUlyF25C8z48OBnD',
#  '0jG92AlXau21qgCQRxGLic',
#  '4Mq2LKAvjc7BnSmiCjzywL',
#  '3ssX20QT5c3nA9wk78V1LQ',
#  '0weAUscowxeqDtpCgtbpgp',
#  '0jSMveIWvnhDIvzqN74Uc7',
#  '1WG3uNOzTWKRwCAfDAlUAW',
#  '3J4YoloryJCieZ9kapS1oL',
#  '0svl7cK07gK1ia5ainczU5',
#  '4rc9kQ6qyssElIccFJgbJb',
#  '3kG2YgxjYnnPBlo7H08Xt3',
#  '68pWLkspLFIfIPPtzyTkQy',
#  '63BcfK6YAzJYeISaTPr6IO',
#  '0ncPdmNqiMvKK1J36Dgr6f',
#  '6YYd5MLpu45J0uLrMdivF7',
#  '2Lg4kvhOrPhpGEZmSe7VAN',
#  '1oTHteQbmJw15rPxPVXUTv',
#  '6jBCehpNMkwFVF3dz4nLIW',
#  '1o7pq0fvaVfQSKOKwQAHSo',
#  '4TJduXYW1Pg96EDNnfiwxJ',
#  '2uiEqPjMmIJXOKplzsEASP',
#  '31bf9SEOppLU6lQ85d8om6',
#  '4LujRMTMwAfFKjm45tixHY',
#  '0LvwrCJtecLr9mnS0h0k7U',
#  '5hALSggfcyvBNLUHY8pvZd',
#  '2tNmhDlMbwQZLxQtWMt2EU',
#  '7MCNnnmwm7TXMh7xyNGohi',
#  '1w3tLFXGmgDPROVf8CoAzv',
#  '6xYSmz5DOEJz14ykNUyUKj',
#  '7hfRrdFJgFKK3cJ4rmkecE',
#  '3Ti0GdlrotgwsAVBBugv0I',
#  '2xsK1pXFX2Dlx7xH33Tc1N',
#  '1LF4nyE8xZJRet2Q5PebJn',
#  '7ixqe1qERxHzAezc4Uq243',
#  '6GfiNirfUb6OQqeDQOelpd',
#  '2DSz4s2QI7Fd8QKZVGNb7T',
#  '1egwcq1nnndit84sSLCuUf',
#  '6PbDGsz1YF8vKNVmn0Lu9c',
#  '3UFSvzLfEL0zPemWzs6wem',
#  '4RUphASXlXEs8SJQvES7N0',
#  '2BPqrPi0M7D7SyGImTRWYS',
#  '5mG9fDwgBlZmFoyOP6dDSE',
#  '3JwaOKoVVv3uTfNBf1RHKK',
#  '20BzuQ18mwBuvOiiJUz6ln',
#  '5lbdS1weHdqfZ6zFWfgt6O',
#  '0z9uYjZDr4HBpjKGvHHvrg',
#  '5HSeVgKT3KaZQPOPhNElmZ',
#  '1Bu2ICXvqpoCM1cmWTyvrJ',
#  '5rzJpM33yH0bHF6XOmmqnb',
#  '0Wgk1WguHMuI03t2sL0w2w',
#  '0Na4LBfBWSf2pmiXzTUSBI',
#  '0XQG2DC9cqB0wIyxEsDsWE',
#  '57SRllQoMoa7aVxT3sqBNt',
#  '6l33m7UxaR3pbNtNa8QARI',
#  '1Fl9fwHWWKewRf3n897kCE',
#  '6L6P4SI85euz5yGQl05Csv',
#  '65pWetzUYhA8MNoAK1dYqu',
#  '3ARH5hY1AP4ympexo2y3Lz',
#  '1AFqQtfrQ0VMLeZxrSPrfM',
#  '6gH1BYRCZ38i5dauknRN60',
#  '7tEgXYCi32cOG6s9Fut8T2',
#  '77EU6IESxSZ6oDJ9S1hMYl',
#  '2CRx925YeUuCmXnb76IGZb',
#  '2BBGv2Tyyv8uxXS1aydkGB',
#  '6eXViRiXJKufjfzY3Ntxhx',
#  '4fGwQjud6qYhPf2Q9vVsME',
#  '2KMc0VMnE5ikCQChB1AdgW',
#  '1444onOjS2vvrBP874CWuT',
#  '6khkrydMjXQzsaWs2oQYRt',
#  '3NOzfsVLR2IUPKp556O2Qh',
#  '6m8SdKl4GQ3TBvsqFlhOGR',
#  '2aMk0jIsihtUONfz7QG8Zb',
#  '70sJapHlYAURB57pDTt6Cd',
#  '7KoBPeQKmwaRNii358LEhl',
#  '4vBHFLY0IkSebkGzOLtzcG',
#  '7oW2II81S5jF0VaULnfKTR',
#  '6BudDSzmev8NZWGND78cfp',
#  '1fb4Tb9t2l1wvM4RgGd5Gd',
#  '03hCREcMFPPTcEUE8slTUX',
#  '6GZG11hUzspxrkfEyfpEyR',
#  '4RzqvV4QyZgCIq19e3OpYM',
#  '2R9oFn24CuFlxZ2sS5uK1w',
#  '6AwGhiAIyt66pboZfYansL',
#  '7jk39nc0yNVVlcAgDaU5ib',
#  '5R13nSy7b5id18TbTScG91',
#  '7H9VxRLBTcdNvowQ1xGH6W',
#  '41SwdQIX8Hy2u6fuEDgvWr',
#  '4YLbQGnk6iIgelpUIwbmxm',
#  '7q2QAMBEbrjRfi9DoeCLwn',
#  '3XnhFQRvNH5LyR9fBKjjh7',
#  '27oiVZe7W0lXNaRGP9toGr',
#  '38xyC5uryAeiprkzLbNF6W',
#  '7mhsGyniumwlhCCzR9Tbxa',
#  '11NwaUSqSYmZrFWo2qO2Ng',
#  '6aDijFwnaEAcnxIRZkikAg',
#  '4j0lSW432dK6awGjED4PPt',
#  '0xnlNEcXQJYcZihI73YTHv',
#  '0ufCBxOl6vL8Yhcu2Jl2a4',
#  '0pHIXg5oIMS9U1u99VWtQS',
#  '5dC6qFGuR0K6sestrISXcv',
#  '3So45HvOkSmZvqOnzXEgMd',
#  '1nPgx4Q9edLlooxkg46HrA',
#  '2do2MZUahp36k3O4dcJ4KM',
#  '2dhPGfqPl8LEXqRiU8tfPl',
#  '1M7T3wMnXOrX9Ybevs1fFh',
#  '0U9NUihXBfEAwrEp5QzeCJ',
#  '003oYjviEtMybWtnTa0lln',
#  '49IoKe4k5cojTVuyLJYWVK',
#  '6TGoYBjxwsLgIzaw9lhfMG',
#  '2ygZBYHY5708auyuPShucL',
#  '0dK65MHzlEfrImScmaNNvl',
#  '1utUrkRSWxiO3PABHq08eG',
#  '7vqvofpdHhCztDuQVBjbRe',
#  '2wuGCJX1moO4WM3ngRzMQu',
#  '42EtLWuJGvehSzXBUdmE3z',
#  '0vweEN9znBHAKMjZ1E86rI',
#  '6WLXkLuiXJbyOdIAk6KJ32',
#  '4RfnepPBWOlB4NMJOpjMaV',
#  '5eUbSzFwUnT2eKMNZkzQk8',
#  '5MOblOnp8VFUW1UlehGHhp',
#  '0Nw7GJIkUDhZa2l2UgJYln',
#  '4alrTMOdEvbDZw84RY2aHm',
#  '6BzeKeT9hluukvZzZTz9PK',
#  '10TN0WSmKI3O6yJuRNblYg',
#  '6AtGyzSSN3Js4fSRPimqxK',
#  '31OvR8h0CeCimvlkE7C0XN',
#  '4wBUpvjmu7nj1pa9zByPvH',
#  '4TGjwsagd5o3IPp1TbCtuq',
#  '5qeIAwW9nhHzpiKkPHusPY',
#  '3Mt7g4wEqa08GGhoUH1Ghk',
#  '6TNBx9lvDcqLq1GQCPNJqH',
#  '3UYKvI6JYzkp8eep9fcWT0',
#  '5S5Cf673GkmYWBJNcGAVuP',
#  '2yZSoKLhnSH9UlAIhYggRv',
#  '13vTvs5XNIsG2jbP0MZEv6',
#  '4K1xINi3pb720zaJxu7In8',
#  '3ylgNkwA5u4NDJmVZIQWaz',
#  '3bOvyoDhBUnLf8NisLxGn6',
#  '47Kg8rGMqxujhTzpOCnClN',
#  '5oPCxuHNsH5JLWq6l5bIyK',
#  '4lBYIkArQFt2lyK5ejJnxN',
#  '3i97OJms85ExXn3lf9cHF2',
#  '7aIsSMjxPXhC8ZmEh4AF9u',
#  '3yhInewGeB4AzUJKyz3SUR',
#  '0x2O1kXhrVgsZCEpfN2PdV',
#  '1esyt62pq02xPShuaK5OpA',
#  '0B7NDkUdIgStXyxSRjWjp3',
#  '1D4GkNWWjnsygYIo2PvQdm',
#  '33SaarwnwkNiZ67qqGl55f',
#  '4AMw3vWRQxJJSCv0WVvofD',
#  '0DM18A05szZlCVYgbFRRnw',
#  '5lJ8vpDjeVdMsbHFf4unWR',
#  '3R6FntVNKj4DNywzoXb8uv',
#  '2GWMfWHvLixgTo9s5NGn3w',
#  '6PQ3nRYazKnSnj0sYnqfly',
#  '2cXOqys4hyhCdwy4qp6hYD',
#  '3yhlH8lhTpS03d91kuwjpf',
#  '0MfnCwZACV6szCJsHoCBAc',
#  '4U4zHjsV1xUCIT5XrEPUSC',
#  '0QLSG6bDQWfNNMOjldi3ym',
#  '14KUweApw0Plx1eDyGvmHz',
#  '4qiMxocFymeATNBYItzHcP',
#  '2c32lDqOdhY1PxTdgEihmg',
#  '0rcle0t0B84myn9wJmMouh',
#  '6x5GocUaxkUhUnSACQbU5y',
#  '1T8gXuMIaGj75AsbQSNL0E',
#  '6pqAWnKK96vhgdIzZMCyEv',
#  '4UtIwr6PnsoOKNMz1LXRT7',
#  '5SQy4wrGwaSDduKzpSK85z',
#  '5XpqjjhQpizXKEwcaDMpKn',
#  '3Wl8hnFfVf47sA3LeOGTLw',
#  '3UbgYcPVG6baxNXt38gLbn',
#  '5fD1cUWzVmReobKb6d24ft',
#  '60y3oBiHHIlOzUFZRWP6Ak',
#  '6eMOT397wvdZShck4In1cG',
#  '77Ecj3uop8nFK6RagnTQCu',
#  '0Z0kcymSbOZ2Fc7tP57FvM',
#  '3tzKPyM6lNG2bRzFyQodXD',
#  '4jO8083M3w7bqvTmz0QSrL',
#  '4jeYP6D3U8vIWQhHUVG3fh',
#  '2YLho363MlxOWrGjmAn65Q',
#  '1qIOc7ciawp9BoIy0S4a81',
#  '5oHjw5NRUOyxwM34rs8ROv',
#  '5MaftJhkfPQEN1jYbkCYC1',
#  '2THYSdShsssHT5RBvgHrjm',
#  '2rwxsA3kNJj8ycasZGU1DS']

# %%
ff = api.get_feats(track)

# %%
ff
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.706   0.931    0    -3.053     0       0.0456        0.3540
# 1           0.744   0.790    8    -4.617     0       0.0562        0.0547
# 2           0.790   0.746    9    -5.960     1       0.0502        0.2410
# 3           0.588   0.830    5    -6.188     0       0.0521        0.0074
# 4           0.693   0.915   11    -5.342     0       0.0453        0.0699
# ..            ...     ...  ...       ...   ...          ...           ...
# 610         0.773   0.720    0    -8.642     1       0.1750        0.0279
# 611         0.560   0.348    5    -4.507     0       0.0504        0.3870
# 612         0.571   0.528    2    -4.776     0       0.0416        0.7360
# 613         0.610   0.577    7    -6.350     1       0.0615        0.3090
# 614         0.268   0.405    1    -9.606     1       0.0452        0.0946
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000004    0.1460   0.4650  123.012  audio_features
# 1            0.000802    0.3200   0.8470  125.002  audio_features
# 2            0.000000    0.3160   0.5380  124.971  audio_features
# 3            0.000000    0.1460   0.5850  124.953  audio_features
# 4            0.000056    0.1140   0.5040  125.013  audio_features
# ..                ...       ...      ...      ...             ...
# 610          0.002630    0.2960   0.1790  122.036  audio_features
# 611          0.000000    0.1140   0.2350  199.432  audio_features
# 612          0.000004    0.0993   0.2630  112.173  audio_features
# 613          0.000280    0.2790   0.4350  139.909  audio_features
# 614          0.297000    0.1040   0.0524  107.059  audio_features
#
#                          id                                   uri  \
# 0    5qiQbOa6AFEO3P111y9Jry  spotify:track:5qiQbOa6AFEO3P111y9Jry
# 1    23Q3zB4aIt4vvGknhBSE7O  spotify:track:23Q3zB4aIt4vvGknhBSE7O
# 2    4raMIjIjMc8JohHth7l9lG  spotify:track:4raMIjIjMc8JohHth7l9lG
# 3    49jQjsgh1bqjLW1UXGPIj2  spotify:track:49jQjsgh1bqjLW1UXGPIj2
# 4    2dzmO8gQgQQBFchqng9MKx  spotify:track:2dzmO8gQgQQBFchqng9MKx
# ..                      ...                                   ...
# 610  1qIOc7ciawp9BoIy0S4a81  spotify:track:1qIOc7ciawp9BoIy0S4a81
# 611  5oHjw5NRUOyxwM34rs8ROv  spotify:track:5oHjw5NRUOyxwM34rs8ROv
# 612  5MaftJhkfPQEN1jYbkCYC1  spotify:track:5MaftJhkfPQEN1jYbkCYC1
# 613  2THYSdShsssHT5RBvgHrjm  spotify:track:2THYSdShsssHT5RBvgHrjm
# 614  2rwxsA3kNJj8ycasZGU1DS  spotify:track:2rwxsA3kNJj8ycasZGU1DS
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/5qiQbOa6AFEO...
# 1    https://api.spotify.com/v1/tracks/23Q3zB4aIt4v...
# 2    https://api.spotify.com/v1/tracks/4raMIjIjMc8J...
# 3    https://api.spotify.com/v1/tracks/49jQjsgh1bqj...
# 4    https://api.spotify.com/v1/tracks/2dzmO8gQgQQB...
# ..                                                 ...
# 610  https://api.spotify.com/v1/tracks/1qIOc7ciawp9...
# 611  https://api.spotify.com/v1/tracks/5oHjw5NRUOyx...
# 612  https://api.spotify.com/v1/tracks/5MaftJhkfPQE...
# 613  https://api.spotify.com/v1/tracks/2THYSdShsssH...
# 614  https://api.spotify.com/v1/tracks/2rwxsA3kNJj8...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/5qiQ...       200893
# 1    https://api.spotify.com/v1/audio-analysis/23Q3...       188640
# 2    https://api.spotify.com/v1/audio-analysis/4raM...       212280
# 3    https://api.spotify.com/v1/audio-analysis/49jQ...       192000
# 4    https://api.spotify.com/v1/audio-analysis/2dzm...       159184
# ..                                                 ...          ...
# 610  https://api.spotify.com/v1/audio-analysis/1qIO...       190961
# 611  https://api.spotify.com/v1/audio-analysis/5oHj...       221969
# 612  https://api.spotify.com/v1/audio-analysis/5Maf...       208633
# 613  https://api.spotify.com/v1/audio-analysis/2THY...       210915
# 614  https://api.spotify.com/v1/audio-analysis/2rwx...       249120
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 610               4
# 611               4
# 612               4
# 613               4
# 614               4
#
# [615 rows x 18 columns]

# %%
track = track.join(ff)

# %%
track.to_csv('data/random3.csv')

# %%
track
# Out:
#                               track_name         artist  \
# 0               Mad Love - Blinkie Remix          Mabel
# 1                                  Sorry     Joel Corry
# 2             Bruises - Steve Void Remix  Lewis Capaldi
# 3    Wish You Well - Benny Benassi Remix         Sigala
# 4                              About You      Papa Zeus
# ..                                   ...            ...
# 610                        See Man Smile   Murkage Dave
# 611                           Monochrome            AMA
# 612                         Talk in Code   Hannah Lucia
# 613                           The Middle          Monro
# 614                   Can't Show My Face         TENDER
#
#                                album release_date  explicit  \
# 0                 Mad Love (Remixes)   2019-07-05     False
# 1                              Sorry   2019-04-05     False
# 2                         Bruises EP   2019-09-27     False
# 3            Wish You Well (Remixes)   2019-07-05     False
# 4                          About You   2019-07-26     False
# ..                               ...          ...       ...
# 610     Murkage Dave Changed My Life   2018-10-19     False
# 611                       Monochrome   2018-11-22     False
# 612                     Talk in Code   2019-04-19     False
# 613                         Deep End   2018-12-05      True
# 614  Bottled Up / Can't Show My Face   2018-12-07     False
#
#                    track_id                             track_uri  \
# 0    5qiQbOa6AFEO3P111y9Jry  spotify:track:5qiQbOa6AFEO3P111y9Jry
# 1    23Q3zB4aIt4vvGknhBSE7O  spotify:track:23Q3zB4aIt4vvGknhBSE7O
# 2    4raMIjIjMc8JohHth7l9lG  spotify:track:4raMIjIjMc8JohHth7l9lG
# 3    49jQjsgh1bqjLW1UXGPIj2  spotify:track:49jQjsgh1bqjLW1UXGPIj2
# 4    2dzmO8gQgQQBFchqng9MKx  spotify:track:2dzmO8gQgQQBFchqng9MKx
# ..                      ...                                   ...
# 610  1qIOc7ciawp9BoIy0S4a81  spotify:track:1qIOc7ciawp9BoIy0S4a81
# 611  5oHjw5NRUOyxwM34rs8ROv  spotify:track:5oHjw5NRUOyxwM34rs8ROv
# 612  5MaftJhkfPQEN1jYbkCYC1  spotify:track:5MaftJhkfPQEN1jYbkCYC1
# 613  2THYSdShsssHT5RBvgHrjm  spotify:track:2THYSdShsssHT5RBvgHrjm
# 614  2rwxsA3kNJj8ycasZGU1DS  spotify:track:2rwxsA3kNJj8ycasZGU1DS
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.706   0.931    0    -3.053     0       0.0456        0.3540
# 1           0.744   0.790    8    -4.617     0       0.0562        0.0547
# 2           0.790   0.746    9    -5.960     1       0.0502        0.2410
# 3           0.588   0.830    5    -6.188     0       0.0521        0.0074
# 4           0.693   0.915   11    -5.342     0       0.0453        0.0699
# ..            ...     ...  ...       ...   ...          ...           ...
# 610         0.773   0.720    0    -8.642     1       0.1750        0.0279
# 611         0.560   0.348    5    -4.507     0       0.0504        0.3870
# 612         0.571   0.528    2    -4.776     0       0.0416        0.7360
# 613         0.610   0.577    7    -6.350     1       0.0615        0.3090
# 614         0.268   0.405    1    -9.606     1       0.0452        0.0946
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000004    0.1460   0.4650  123.012  audio_features
# 1            0.000802    0.3200   0.8470  125.002  audio_features
# 2            0.000000    0.3160   0.5380  124.971  audio_features
# 3            0.000000    0.1460   0.5850  124.953  audio_features
# 4            0.000056    0.1140   0.5040  125.013  audio_features
# ..                ...       ...      ...      ...             ...
# 610          0.002630    0.2960   0.1790  122.036  audio_features
# 611          0.000000    0.1140   0.2350  199.432  audio_features
# 612          0.000004    0.0993   0.2630  112.173  audio_features
# 613          0.000280    0.2790   0.4350  139.909  audio_features
# 614          0.297000    0.1040   0.0524  107.059  audio_features
#
#                          id                                   uri  \
# 0    5qiQbOa6AFEO3P111y9Jry  spotify:track:5qiQbOa6AFEO3P111y9Jry
# 1    23Q3zB4aIt4vvGknhBSE7O  spotify:track:23Q3zB4aIt4vvGknhBSE7O
# 2    4raMIjIjMc8JohHth7l9lG  spotify:track:4raMIjIjMc8JohHth7l9lG
# 3    49jQjsgh1bqjLW1UXGPIj2  spotify:track:49jQjsgh1bqjLW1UXGPIj2
# 4    2dzmO8gQgQQBFchqng9MKx  spotify:track:2dzmO8gQgQQBFchqng9MKx
# ..                      ...                                   ...
# 610  1qIOc7ciawp9BoIy0S4a81  spotify:track:1qIOc7ciawp9BoIy0S4a81
# 611  5oHjw5NRUOyxwM34rs8ROv  spotify:track:5oHjw5NRUOyxwM34rs8ROv
# 612  5MaftJhkfPQEN1jYbkCYC1  spotify:track:5MaftJhkfPQEN1jYbkCYC1
# 613  2THYSdShsssHT5RBvgHrjm  spotify:track:2THYSdShsssHT5RBvgHrjm
# 614  2rwxsA3kNJj8ycasZGU1DS  spotify:track:2rwxsA3kNJj8ycasZGU1DS
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/5qiQbOa6AFEO...
# 1    https://api.spotify.com/v1/tracks/23Q3zB4aIt4v...
# 2    https://api.spotify.com/v1/tracks/4raMIjIjMc8J...
# 3    https://api.spotify.com/v1/tracks/49jQjsgh1bqj...
# 4    https://api.spotify.com/v1/tracks/2dzmO8gQgQQB...
# ..                                                 ...
# 610  https://api.spotify.com/v1/tracks/1qIOc7ciawp9...
# 611  https://api.spotify.com/v1/tracks/5oHjw5NRUOyx...
# 612  https://api.spotify.com/v1/tracks/5MaftJhkfPQE...
# 613  https://api.spotify.com/v1/tracks/2THYSdShsssH...
# 614  https://api.spotify.com/v1/tracks/2rwxsA3kNJj8...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/5qiQ...       200893
# 1    https://api.spotify.com/v1/audio-analysis/23Q3...       188640
# 2    https://api.spotify.com/v1/audio-analysis/4raM...       212280
# 3    https://api.spotify.com/v1/audio-analysis/49jQ...       192000
# 4    https://api.spotify.com/v1/audio-analysis/2dzm...       159184
# ..                                                 ...          ...
# 610  https://api.spotify.com/v1/audio-analysis/1qIO...       190961
# 611  https://api.spotify.com/v1/audio-analysis/5oHj...       221969
# 612  https://api.spotify.com/v1/audio-analysis/5Maf...       208633
# 613  https://api.spotify.com/v1/audio-analysis/2THY...       210915
# 614  https://api.spotify.com/v1/audio-analysis/2rwx...       249120
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 610               4
# 611               4
# 612               4
# 613               4
# 614               4
#
# [615 rows x 25 columns]

# %%
random_playlists
# Out:
# []

# %%
playlists
# Out:
# ['spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso',
#  'spotify:playlist:37i9dQZF1DWY4lFlS4Pnso']

# %%
df1 = pd.read_csv('data/random.csv')

# %%
df2 = pd.read_csv('data/random2.csv')

# %%
df3 = pd.concat([df1,df2])
df3.reset_index(inplace=True)

# %%
df3.drop(columns=['index','analysis_url','track_href','uri','id'], inplace=True)

# %%
df.drop(columns = ['Unnamed: 0', 'type','album','artist','track_name'], inplace=True)

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'track_name', 'artist', 'album', 'release_date',
#        'explicit', 'track_id', 'track_uri', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %%
'Unnamed: 0', 'acousticness', 'album', 'artist', 'danceability',
       'duration_ms', 'energy', 'explicit', 'genre', 'instrumentalness', 'key',
       'liveness', 'loudness', 'mode', 'release_date', 'speechiness', 'tempo',
       'time_signature', 'track_id', 'track_name', 'type', 'valence'],
      dtype='object')

# %%
df3.to_csv('data/random_full.csv')
