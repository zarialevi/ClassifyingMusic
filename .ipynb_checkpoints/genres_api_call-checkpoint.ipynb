# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import requests
import json
from IPython.display import clear_output
import pickle

# %%
tracks_df = pd.read_csv('99_19_songs.csv')

# %%
tracks_df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1 artist_name release_date            track_name  \
# 0           0             0         TLC   1999-02-23             No Scrubs
# 1           1             1   blink-182   1999-06-01  All The Small Things
#
#                  track_id  popularity  acousticness  danceability  \
# 0  1KGi9sZVMeszgZOWivFpxs          81        0.0251         0.743
# 1  2m1hi0nfMR9vdGC8UcrnwU          80        0.0103         0.434
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       214400   0.675          0.000717    8    0.0685    -4.267     0
# 1       167067   0.897          0.000000    0    0.6120    -4.918     1
#
#    speechiness    tempo  time_signature  valence
# 0       0.0953   92.909               4    0.590
# 1       0.0488  148.726               4    0.684

# %%
def get_auth():
    CLIENT_ID ='50b2240e93784d028ba2eb626095dd6c'
    CLIENT_SECRET = '07e055a4f4fe4b9d83ad3e6961bb40f2'

    credentials = SpotifyClientCredentials(
            client_id=CLIENT_ID,
            client_secret=CLIENT_SECRET)

    token = credentials.get_access_token()
    return "Bearer " + token

oath = get_auth()

# %%
artist_id_lst = []
genres_lst = []
counter = 0
for row in track_id_lt:
    clear_output()
    
    r = requests.get(
        f"https://api.spotify.com/v1/tracks/{row}",
        headers={ "Accept": "application/json", "Content-Type": "application/json", "Authorization": get_auth()})
        
    artist_info =r.json()
    
        
    artist_id = artist_info['album']['artists'][0]['id']
    artist_id_lst.append(artist_id)
    
    
        

    q = requests.get(
        f"https://api.spotify.com/v1/artists/{artist_id}",
        headers={ "Accept": "application/json", "Content-Type": "application/json", "Authorization": get_auth()})


    genre_info =q.json()
    try:
        genres_lst.append({ "genres" : genre_info['genres'], "popularity" : genre_info['popularity'], "followers": genre['followers']['total']})
    
    except:
        genres_lst.append({ "genres" : np.nan, "popularity" : np.nan, "followers": np.nan})
    
    counter += 1 
    
    
    print(counter)
# Out:
# 96247

# %%
print(artist_id_lst)
print(genres_lst)
# Out:
# ['0LyfQWJT6nXafLPZqxe9Of']
# []

# %%
q = requests.get(
    f"https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of",
    headers={ "Accept": "application/json", "Content-Type": "application/json", "Authorization": get_auth()})


genre =q.json()
genre
# artist_id.append(dat['album']['artists'][0]['id'])
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#  'followers': {'href': None, 'total': 767073},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#  'id': '0LyfQWJT6nXafLPZqxe9Of',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/8987540724d78afbf9f9249638eefcef38c0853b',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/3439f512b1422283239d93985959dc6115eae9c2',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/51820ee3bf05021dc690ee7bf804b6d73eedb4a1',
#    'width': 160}],
#  'name': 'Various Artists',
#  'popularity': 0,
#  'type': 'artist',
#  'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}

# %%
genre['followers']['total']
# Out:
# 767073

# %%
genre['genres']
# Out:
# []

# %%
genre['popularity']
# Out:
# 0

# %%
len(artist_id_lst)
# Out:
# 105460

# %%
len(genres_lst)
# Out:
# 914

# %%
tracks_df['artist_name'].value_counts()
# Out:
# Ludwig van Beethoven     1553
# Johann Sebastian Bach     512
# Glee Cast                 362
# Hans Zimmer               262
# $uicideBoy$               260
#                          ...
# The Rouse Brothers          1
# Sarah Peasall               1
# John Patitucci              1
# Dimension Costena           1
# David Halliday              1
# Name: artist_name, Length: 31191, dtype: int64

# %%
artist = list(tracks_df['artist_name'].unique())

# %%
len(artist)
# Out:
# 31191

# %%
p = requests.get(
    f"https://api.spotify.com/v1/audio-analysis/1KGi9sZVMeszgZOWivFpxs",
    headers={ "Accept": "application/json", "Content-Type": "application/json", "Authorization": get_auth()})


analysis =p.json()
analysis
# Out:
# {'meta': {'analyzer_version': '4.0.0',
#   'platform': 'Linux',
#   'detailed_status': 'OK',
#   'status_code': 0,
#   'timestamp': 1574231635,
#   'analysis_time': 7.08448,
#   'input_process': 'libvorbisfile L+R 44100->22050'},
#  'track': {'num_samples': 4727520,
#   'duration': 214.4,
#   'sample_md5': '',
#   'offset_seconds': 0,
#   'window_seconds': 0,
#   'analysis_sample_rate': 22050,
#   'analysis_channels': 1,
#   'end_of_fade_in': 0.10989,
#   'start_of_fade_out': 204.65488,
#   'loudness': -4.267,
#   'tempo': 92.909,
#   'tempo_confidence': 0.101,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'key': 8,
#   'key_confidence': 0.69,
#   'mode': 0,
#   'mode_confidence': 0.496,
# ...

# %%
tracks_df.iloc[105459:105464]
# Out:
#         Unnamed: 0  Unnamed: 0.1                   artist_name release_date  \
# 105459        8757          8757            Conjunto Atardecer   2009-05-07
# 105460        8758          8758           Neil Patrick Harris   2009-01-14
# 105461        8759          8759                 Carole Samaha   2009-03-15
# 105462        8760          8760  University of Oklahoma Bands   2009-01-01
# 105463        8761          8761                  Rachel Liang   2009-01-01
#
#                          track_name                track_id  popularity  \
# 105459  Niña, ¿Qué Tienen Tus Ojos?  32x0zE1ks0XUiuD1q4qdVi          29
# 105460        I'm The Music Meister  3ILT3S8sA9KkHHZZtxK6MO          31
# 105461              Khallik Behalak  3bAvwg6hN7JGdd8z7uabNP          40
# 105462               Sweet Caroline  3jId4BMEJOwwRQURiqn1Gj          29
# 105463                        愛一直存在  3z5MabmnwlfuOK1n1qPnKx          44
#
# ...

# %%
pickle_out = open("artist2.pickle","wb")
pickle.dump(artist_id_lst, pickle_out)
pickle_out.close()

# %%
pickle_out = open("genres2.pickle","wb")
pickle.dump(genres_lst, pickle_out)
pickle_out.close()

# %%
artist_id_lst[-1]
# Out:
# '5Q9lZeceisTLfkThW0fd94'

# %%
genres_lst[-1]
# Out:
# {'genres': ['banda',
#   'duranguense',
#   'grupera',
#   'norteno',
#   'norteno-sax',
#   'regional mexican'],
#  'popularity': 51,
#  'followers': 1852892}

# %%
track_id_lt = list(tracks_df['track_id'].iloc[105460:])

# %%
len(track_id_lt)
# Out:
# 96247

# %%
pickle_in = open("artist.pickle","rb")
atist_id_lst1 = pickle.load(pickle_in)

# %%
artist_id_lst_full = atist_id_lst1 + artist_id_lst

# %%
len(artist_id_lst_full)
# Out:
# 201707

# %%
tracks_df.shape
# Out:
# (201707, 20)

# %%
pickle_in = open("genres.pickle","rb")
genres_lst1 = pickle.load(pickle_in)

# %%
genres_lst_full = genres_lst1 + genres_lst

# %%
len(genres_lst_full)
# Out:
# 201707

# %%
pickle_out = open("genres_full.pickle","wb")
pickle.dump(genres_lst_full, pickle_out)
pickle_out.close()

# %%
pickle_in = open("genres_full.pickle","rb")
genres_lst_full = pickle.load(pickle_in)

# %%
genres_df = pd.DataFrame(genres_lst_full)

# %%
genres_df.head(20)
# Out:
#                                                genres  popularity  followers
# 0   [atl hip hop, dance pop, girl group, hip hop, ...          73    1852892
# 1                    [pop punk, punk, socal pop punk]          83    1852892
# 2           [alternative rock, pop rock, post-grunge]          71    1852892
# 3   [dance pop, girl group, hip pop, pop, pop rap,...          76    1852892
# 4   [alternative rock, funk metal, funk rock, perm...          86    1852892
# 5                    [pop punk, punk, socal pop punk]          83    1852892
# 6   [g funk, gangster rap, hip hop, rap, west coas...          81    1852892
# 7   [g funk, gangster rap, hip hop, rap, west coas...          81    1852892
# 8   [alternative rock, pop rock, post-grunge, soca...          60    1852892
# 9   [alternative metal, alternative rock, funk met...          73    1852892
# 10                                                 []           0    1852892
# ...

# %%
genresdf2 = genres_df.genres.apply(pd.Series)

# %%
genresdf.head()
# Out:
#                  0           1               2               3            4   \
# 0       atl hip hop   dance pop      girl group         hip hop      hip pop
# 1          pop punk        punk  socal pop punk             NaN          NaN
# 2  alternative rock    pop rock     post-grunge             NaN          NaN
# 3         dance pop  girl group         hip pop             pop      pop rap
# 4  alternative rock  funk metal       funk rock  permanent wave  post-grunge
#
#                5                   6        7    8                   9   ...  \
# 0  new jack swing                 pop  pop rap  r&b  urban contemporary  ...
# 1             NaN                 NaN      NaN  NaN                 NaN  ...
# 2             NaN                 NaN      NaN  NaN                 NaN  ...
# 3             r&b  urban contemporary      NaN  NaN                 NaN  ...
# 4            rock                 NaN      NaN  NaN                 NaN  ...
#
# ...

# %%
len(genresdf[0].unique())
# Out:
# 449

# %%
genresdf[0].unique()
# Out:
# array(['hip hop', 'rock', 'pop', 'rap', 'metal', nan, 'oldies', 'country',
#        'disco', 'latin', 'indie', 'r&b', 'reggae', 'classical',
#        'soundtrack', 'jazz', 'alternative', 'edm', 'permanent wave',
#        'folk', 'bachata', 'idm', 'hawaiian', 'norteno', 'bolero',
#        'religious', 'banjo', 'german dance', 'bakersfield sound',
#        'children', 'cantautor', 'cartoon', 'healing', 'comic',
#        'classic opm', 'native american', 'guaracha', 'dreamo', 'boogaloo',
#        'vallenato', 'new age', 'celtic', 'blues', 'flamenco',
#        'calming instrumental', 'merengue', 'psychobilly', 'mariachi',
#        'louvor', 'bounce', 'experimental', 'bubblegum dance', 'big beat',
#        'abstract', 'freestyle', 'doo-wop', 'avant-garde', 'adventista',
#        'hollywood', 'eurodance', 'novelty', 'bhangra', 'comedy', 'chicha',
#        'tropical', 'dark wave', 'tejano', 'dark cabaret', 'a cappella',
#        'chanson', 'ranchera', 'show tunes', 'aggrotech', 'beatdown',
# ...

# %%
rock = ['rock', 'punk',  'jam band', 'grunge']
hip_hop = ["hip hop", 'crunk', 'new jack']
rap = ['rap', 'g funk', 'drill', 'grime']
blues = ['blues']
jazz = ['jazz', 'ragtime', 'bossa nova', 'bebop', 'swing', 'dixieland', 'contrabass']
r_n_b = ['r&b', 'soul', "motown",'gospel','funk']
metal = ['metal','hardcore', 'core', 'thrash']
country= ['country', 'nashville','bluegrass', 'western', 'stomp and holler', 'honky tonk']
pop = ['pop', 'boy band', 'girl group', 'surf']
indie = ['indie','neo mellow', 'shoegaze', "singer-songwriter"]
classical = ['classical','orchestral','string quartet', 'ballet', 'ensemble','ballroom','choir','romantic era','military','band', 'baroque', 'viola', 'cello', 
             'orchestra', 'renaissance', 'opera']
oldies = ['oldies', 'adult standard']
latin = ['latin','chunchaca','grupera', 'banda', 'dominican','champeta','cumbia','mexic','cuba', 'salsa', 'venezolano', 'brazil', 'marimba', 'rumba', 'tango']
arabic =['arabic', 'arab', 'ghazal', 'nasheed', 'dabke']
indian = ['indian', 'bollywood', 'sitar']
eastern_european = ['eastern european', ]
carribean = ['carribean', 'mambo', 'calypso']
african = ['african', 'afrobeat', 'afro']
edm = ['edm', 'downtempo', 'house', 'techno', 'electro','garage', 'jungle','trance','tronica', 'drum and bass', 'dnb', 'deep liquid bass', 'drill and bass', 
       'bassline', 'big room', 'sky room', 'deep flow', 'bass']
japanese = ['japanese', 'j-']
korean = ['korean', 'k-']
idm = ['idm','ambient', 'chill', 'trip']
folk = ['folk', 'americana']
soundtrack = ['soundtrack','movie','anime', 'video game', 'broadway', 'west end', 'disney', 'theme']
children = ['children', 'kinder', 'enfants', 'nursery', 'infantil', 'lullaby']
religious = ['religious','chant','praise','ccm', 'worship', 'christian', 'spiritual', 'islam', 'anglican','cristiano', 'gaze']
celtic = ['celtic', 'irish']
white_noise = ['white noise', 'atmosphere']
alternative = ['alternative', 'downshift', 'emo']
disco = ['disco']
reggae = ['reggae', 'dub', 'ska', 'soca', 'ragga', 'dancehall']
meditation = ['meditation', 'chakra']
comedy = ['comedy']
avant_garde = ['lo-fi']
world = [ 'world']

# %%
lst_of_genres = [rock, hip_hop, rap, blues, jazz, r_n_b, metal, country, pop, indie, classical, reggae, oldies, latin, folk, arabic, indian, eastern_european, carribean,
                 african, edm, idm, soundtrack, children, religious, japanese, korean, celtic, white_noise, alternative, disco, meditation, comedy, avant_garde, world]

# %%
for genres in lst_of_genres:
    for sub in genres:
         genresdf.loc[genresdf[0].str.contains(sub, na=False)] = genres[0]
    print(genres , 'done')
# Out:
# ['rock', 'punk', 'jam band', 'grunge'] done
# ['hip hop', 'crunk', 'new jack'] done
# ['rap', 'g funk', 'drill', 'grime'] done
# ['blues'] done
# ['jazz', 'ragtime', 'bossa nova', 'bebop', 'swing', 'dixieland', 'contrabass'] done
# ['r&b', 'soul', 'motown', 'gospel', 'funk'] done
# ['metal', 'hardcore', 'core', 'thrash'] done
# ['country', 'nashville', 'bluegrass', 'western', 'stomp and holler', 'honky tonk'] done
# ['pop', 'boy band', 'girl group', 'surf'] done
# ['indie', 'neo mellow', 'shoegaze', 'singer-songwriter'] done
# ['classical', 'orchestral', 'string quartet', 'ballet', 'ensemble', 'ballroom', 'choir', 'romantic era', 'military', 'band', 'baroque', 'viola', 'cello', 'orchestra', 'renaissance', 'opera'] done
# ['reggae', 'dub', 'ska', 'soca', 'ragga', 'dancehall'] done
# ['oldies', 'adult standard'] done
# ['latin', 'chunchaca', 'grupera', 'banda', 'dominican', 'champeta', 'cumbia', 'mexic', 'cuba', 'salsa', 'venezolano', 'brazil', 'marimba', 'rumba', 'tango'] done
# ...

# %%
genresdf.rename(columns = {0:'Genres'}, inplace = True)

# %%
df = tracks_df.join(genresdf['Genres'], rsuffix="_r")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            artist_name release_date  \
# 0           0             0                    TLC   1999-02-23
# 1           1             1              blink-182   1999-06-01
# 2           2             2            Smash Mouth   1999-01-01
# 3           3             3        Destiny's Child   1999-07-27
# 4           4             4  Red Hot Chili Peppers   1999-06-08
#
#              track_name                track_id  popularity  acousticness  \
# 0             No Scrubs  1KGi9sZVMeszgZOWivFpxs          81        0.0251
# 1  All The Small Things  2m1hi0nfMR9vdGC8UcrnwU          80        0.0103
# 2              All Star  3cfOd4CMv2snFaKAnMdnvK          81        0.0319
# 3           Say My Name  7H6ev70Weq6DdpZyyTmUXk          78        0.2730
# 4       Californication  48UPSzbZjgc449aqz8bxox          82        0.0021
#
#    danceability  duration_ms  ...  instrumentalness  key  liveness  loudness  \
# ...

# %%
df = df.iloc[:,2:]

# %%
df.head()
# Out:
#              artist_name release_date            track_name  \
# 0                    TLC   1999-02-23             No Scrubs
# 1              blink-182   1999-06-01  All The Small Things
# 2            Smash Mouth   1999-01-01              All Star
# 3        Destiny's Child   1999-07-27           Say My Name
# 4  Red Hot Chili Peppers   1999-06-08       Californication
#
#                  track_id  popularity  acousticness  danceability  \
# 0  1KGi9sZVMeszgZOWivFpxs          81        0.0251         0.743
# 1  2m1hi0nfMR9vdGC8UcrnwU          80        0.0103         0.434
# 2  3cfOd4CMv2snFaKAnMdnvK          81        0.0319         0.731
# 3  7H6ev70Weq6DdpZyyTmUXk          78        0.2730         0.713
# 4  48UPSzbZjgc449aqz8bxox          82        0.0021         0.592
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       214400   0.675          0.000717    8    0.0685    -4.267     0
# ...

# %%
df.Genres.value_counts()
# Out:
# pop                           33097
# rock                          18097
# metal                         15945
# hip hop                       13063
# classical                     10783
#                               ...
# aggro chileno                     1
# commons                           1
# deep psychobilly                  1
# novos talentos brasileiros        1
# detski pesnichki                  1
# Name: Genres, Length: 448, dtype: int64

# %%
vc = pd.DataFrame(df.Genres.value_counts())

# %%
vc.head(20)
# Out:
#              Genres
# pop           33097
# rock          18097
# metal         15945
# hip hop       13063
# classical     10783
# rap           10229
# country        9871
# latin          7918
# r&b            6747
# alternative    5697
# indie          4644
# edm            4291
# religious      4220
# oldies         3001
# idm            2732
# jazz           2703
# soundtrack     2507
# folk           2082
# reggae         1997
# comedy         1369

# %%
tracks_csv = df.to_csv(r'tracks.csv')

# %%
genresdf2.head()
# Out:
#                  0           1               2               3            4   \
# 0       atl hip hop   dance pop      girl group         hip hop      hip pop
# 1          pop punk        punk  socal pop punk             NaN          NaN
# 2  alternative rock    pop rock     post-grunge             NaN          NaN
# 3         dance pop  girl group         hip pop             pop      pop rap
# 4  alternative rock  funk metal       funk rock  permanent wave  post-grunge
#
#                5                   6        7    8                   9   ...  \
# 0  new jack swing                 pop  pop rap  r&b  urban contemporary  ...
# 1             NaN                 NaN      NaN  NaN                 NaN  ...
# 2             NaN                 NaN      NaN  NaN                 NaN  ...
# 3             r&b  urban contemporary      NaN  NaN                 NaN  ...
# 4            rock                 NaN      NaN  NaN                 NaN  ...
#
# ...

# %%
genresdf2.rename(columns = {0:'subgenres'}, inplace = True)

# %%
genresdf2.head()
# Out:
#           subgenres           1               2               3            4  \
# 0       atl hip hop   dance pop      girl group         hip hop      hip pop
# 1          pop punk        punk  socal pop punk             NaN          NaN
# 2  alternative rock    pop rock     post-grunge             NaN          NaN
# 3         dance pop  girl group         hip pop             pop      pop rap
# 4  alternative rock  funk metal       funk rock  permanent wave  post-grunge
#
#                 5                   6        7    8                   9  ...  \
# 0  new jack swing                 pop  pop rap  r&b  urban contemporary  ...
# 1             NaN                 NaN      NaN  NaN                 NaN  ...
# 2             NaN                 NaN      NaN  NaN                 NaN  ...
# 3             r&b  urban contemporary      NaN  NaN                 NaN  ...
# 4            rock                 NaN      NaN  NaN                 NaN  ...
#
# ...

# %%
df = df.join(genres_df['popularity'], rsuffix="_artist")

# %%
df.head()
# Out:
#              artist_name release_date            track_name  \
# 0                    TLC   1999-02-23             No Scrubs
# 1              blink-182   1999-06-01  All The Small Things
# 2            Smash Mouth   1999-01-01              All Star
# 3        Destiny's Child   1999-07-27           Say My Name
# 4  Red Hot Chili Peppers   1999-06-08       Californication
#
#                  track_id  popularity  acousticness  danceability  \
# 0  1KGi9sZVMeszgZOWivFpxs          81        0.0251         0.743
# 1  2m1hi0nfMR9vdGC8UcrnwU          80        0.0103         0.434
# 2  3cfOd4CMv2snFaKAnMdnvK          81        0.0319         0.731
# 3  7H6ev70Weq6DdpZyyTmUXk          78        0.2730         0.713
# 4  48UPSzbZjgc449aqz8bxox          82        0.0021         0.592
#
#    duration_ms  energy  instrumentalness  ...  liveness  loudness  mode  \
# 0       214400   0.675          0.000717  ...    0.0685    -4.267     0
# ...

# %%
tracks_csv2 = df.to_csv(r'tracks2.csv', index = False)

# %%
df2.duplicated('artist_name').sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9a44034fa024> in <module>
# ----> 1 df2.duplicated('artist_name').sum()
#
# NameError: name 'df2' is not defined
