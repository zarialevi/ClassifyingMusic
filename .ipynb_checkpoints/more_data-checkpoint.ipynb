# %%
import pandas as pd

import json

from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pprint
import requests

import re

pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 90)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

client_credentials_manager = SpotifyClientCredentials(client_id='472d9fe420af4222b7afdd11b9578446', client_secret='518bc9207d064855be7f6300ca080c76')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

import api 

oath = api.get_auth()
playlists = api.get_playlists()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('data/full_working.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'acousticness', 'album', 'artist', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'genre', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'release_date', 'speechiness', 'tempo',
#        'time_signature', 'track_id', 'track_name', 'type', 'valence'],
#       dtype='object')

# %%
df_soc = df.loc[df['genre'] == 'soca']

# %%
unique_artist_soc = list(df_dan['artist'].unique())

# %%
artists_uri = api.get_artists_uri(unique_artist_soc)

# %%
artists_uri
# Out:
#          artist_name                             artist_uri  \
# 0       Nadia Batson  spotify:artist:1m1PGW9tdZRXYn85Bh3w9t
# 1             Destra  spotify:artist:0xMFjTpcN1zaf1ZU5NaNmk
# 2          Marzville  spotify:artist:0EW8oVadcmlxZevZFlPm9P
# 3            Aidonia  spotify:artist:5mYWkDD4b1eM4ZjFq5axxs
# 4    DJ Private Ryan  spotify:artist:1ODw2LIpFN4MPGnah95PBp
# ..               ...                                    ...
# 476   United Sisters  spotify:artist:7aFZDOPtJdwiUVlQMurip7
# 477    Prince Pronto  spotify:artist:1wQkUYwuoRHCynIvy77sx2
# 478  Taurean Everett  spotify:artist:3b8abRXJAuZOTGkiZq10vm
# 479      Pupa Leendi  spotify:artist:3COuCfRwg2wvcWWIeChv4X
# 480     Young Bredda  spotify:artist:1cnMGcnYcA6YLmQeTzW4Ay
#
#                   artist_id
# 0    1m1PGW9tdZRXYn85Bh3w9t
# 1    0xMFjTpcN1zaf1ZU5NaNmk
# 2    0EW8oVadcmlxZevZFlPm9P
# 3    5mYWkDD4b1eM4ZjFq5axxs
# 4    1ODw2LIpFN4MPGnah95PBp
# ..                      ...
# 476  7aFZDOPtJdwiUVlQMurip7
# 477  1wQkUYwuoRHCynIvy77sx2
# 478  3b8abRXJAuZOTGkiZq10vm
# 479  3COuCfRwg2wvcWWIeChv4X
# 480  1cnMGcnYcA6YLmQeTzW4Ay
#
# [481 rows x 3 columns]

# %%
df = api.get_related_artists(artists_uri)

# %%
df
# Out:
#           artist_name                             artist_uri  \
# 0       Fay-Ann Lyons  spotify:artist:4nLVEYSAcpANC0BV87P4rd
# 1        Farmer Nappy  spotify:artist:0zSbNvakUiCGzlvMl7ncaN
# 2       Denise Belfon  spotify:artist:20rSjugHQ6CwKR44JnteQf
# 3     Skinny Fabulous  spotify:artist:56BHYURgbka2nQbBy8XZ3x
# 4       Problem Child  spotify:artist:1lE1SGLNabSpBbJB9A9qtU
# ...               ...                                    ...
# 3983        DJ Spider  spotify:artist:4IIKLm6H0rXxvn6DWNhWcq
# 3984    Problem Child  spotify:artist:4mwylDt7PKfgkb7NII8NGx
# 3985        Marzville  spotify:artist:0EW8oVadcmlxZevZFlPm9P
# 3986       Asa Banton  spotify:artist:5Q3wno9DFhGP6cx8B6n0u5
# 3987          Lavaman  spotify:artist:5UiYnbo5CfmFEgLGCmzqdh
#
#                    artist_id
# 0     4nLVEYSAcpANC0BV87P4rd
# 1     0zSbNvakUiCGzlvMl7ncaN
# 2     20rSjugHQ6CwKR44JnteQf
# 3     56BHYURgbka2nQbBy8XZ3x
# 4     1lE1SGLNabSpBbJB9A9qtU
# ...                      ...
# 3983  4IIKLm6H0rXxvn6DWNhWcq
# 3984  4mwylDt7PKfgkb7NII8NGx
# 3985  0EW8oVadcmlxZevZFlPm9P
# 3986  5Q3wno9DFhGP6cx8B6n0u5
# 3987  5UiYnbo5CfmFEgLGCmzqdh
#
# [3988 rows x 3 columns]

# %%
ids = list(df['artist_id'])

# %%
tracks = api.get_tracks_from_artist(ids)

# %%
tracks
# Out:
#                     track_id                     track_name  \
# 0     3TYvJyZKCO206xrWpF3DIf                          Girls
# 1     4sjoQiP7YBPOfR9I2IWsAe                       Wine Low
# 2     7a3UBZZ4md9nJUDQbxqk7W                    Hookin' Meh
# 3     1mSJ5YhKEuFGEDq6yarGhh                        Day One
# 4     5T5lfc7XDP1rxcB4QDtZTX                   Wining Queen
# ...                      ...                            ...
# 7089  3eM1OyuTO7tYQ4dkRYiMQw            Middle of Something
# 7090  75jyBlvlVkSgjXiQDTWUeS                  Give It to Ya
# 7091  5U3BtEzZtKgkin6H5XQWcf                       Bang Bim
# 7092  6s2YGDofoeyfbJGCL8ebxN  Like Nike - Side Piece Riddim
# 7093  3Z0H46wO0WYKS73eLm1ipa                        Mad Jab
#
#                                  track_uri                    artist_name
# 0     spotify:track:3TYvJyZKCO206xrWpF3DIf                Break The World
# 1     spotify:track:4sjoQiP7YBPOfR9I2IWsAe                       Wine Low
# 2     spotify:track:7a3UBZZ4md9nJUDQbxqk7W                 Hooked on Soca
# 3     spotify:track:1mSJ5YhKEuFGEDq6yarGhh                 Hooked on Soca
# 4     spotify:track:5T5lfc7XDP1rxcB4QDtZTX               Project 5 Riddim
# ...                                    ...                            ...
# 7089  spotify:track:3eM1OyuTO7tYQ4dkRYiMQw           Problem Is a Problem
# 7090  spotify:track:75jyBlvlVkSgjXiQDTWUeS                  Give It to Ya
# 7091  spotify:track:5U3BtEzZtKgkin6H5XQWcf             One O'clock Riddim
# 7092  spotify:track:6s2YGDofoeyfbJGCL8ebxN  Like Nike (Side Piece Riddim)
# 7093  spotify:track:3Z0H46wO0WYKS73eLm1ipa              Planet Jab Riddim
#
# [7094 rows x 4 columns]

# %%
# tracks.to_csv('data/dancehall_temp.csv')

# %%
full = api.get_feats(tracks[:3])

# %%
fulle = api.get_feats(tracks[:3500])

# %%
fuller = api.get_feats(tracks)
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs

# %%
fuller
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.778   0.767    1    -2.743     1       0.1520       0.13100
# 1            0.873   0.733    1    -4.162     1       0.1060       0.13400
# 2            0.844   0.958   11    -3.666     1       0.0727       0.16100
# 3            0.577   0.945    1    -3.420     1       0.0664       0.09050
# 4            0.926   0.781    9    -6.455     1       0.0932       0.04930
# ...            ...     ...  ...       ...   ...          ...           ...
# 7089         0.820   0.893    2    -3.251     1       0.0486       0.25900
# 7090         0.854   0.911    0    -3.957     1       0.0417       0.00458
# 7091         0.655   0.756    7    -2.557     1       0.3440       0.09530
# 7092         0.854   0.903    1    -3.453     1       0.1260       0.36600
# 7093         0.806   0.890   11    -2.501     0       0.1780       0.52000
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.0461    0.877  119.845  audio_features
# 1             0.000000    0.0854    0.713  108.022  audio_features
# 2             0.000000    0.3010    0.935  106.006  audio_features
# 3             0.000000    0.4990    0.855  131.343  audio_features
# 4             0.000306    0.0690    0.905  122.042  audio_features
# ...                ...       ...      ...      ...             ...
# 7089          0.089500    0.0942    0.526  107.998  audio_features
# 7090          0.000000    0.0267    0.638  107.927  audio_features
# 7091          0.000007    0.2550    0.775  191.764  audio_features
# 7092          0.000000    0.4190    0.849  129.964  audio_features
# 7093          0.012700    0.1360    0.713  161.976  audio_features
#
#                           id                                   uri  \
# 0     3TYvJyZKCO206xrWpF3DIf  spotify:track:3TYvJyZKCO206xrWpF3DIf
# 1     4sjoQiP7YBPOfR9I2IWsAe  spotify:track:4sjoQiP7YBPOfR9I2IWsAe
# 2     7a3UBZZ4md9nJUDQbxqk7W  spotify:track:7a3UBZZ4md9nJUDQbxqk7W
# 3     1mSJ5YhKEuFGEDq6yarGhh  spotify:track:1mSJ5YhKEuFGEDq6yarGhh
# 4     5T5lfc7XDP1rxcB4QDtZTX  spotify:track:5T5lfc7XDP1rxcB4QDtZTX
# ...                      ...                                   ...
# 7089  3eM1OyuTO7tYQ4dkRYiMQw  spotify:track:3eM1OyuTO7tYQ4dkRYiMQw
# 7090  75jyBlvlVkSgjXiQDTWUeS  spotify:track:75jyBlvlVkSgjXiQDTWUeS
# 7091  5U3BtEzZtKgkin6H5XQWcf  spotify:track:5U3BtEzZtKgkin6H5XQWcf
# 7092  6s2YGDofoeyfbJGCL8ebxN  spotify:track:6s2YGDofoeyfbJGCL8ebxN
# 7093  3Z0H46wO0WYKS73eLm1ipa  spotify:track:3Z0H46wO0WYKS73eLm1ipa
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3TYvJyZKCO20...
# 1     https://api.spotify.com/v1/tracks/4sjoQiP7YBPO...
# 2     https://api.spotify.com/v1/tracks/7a3UBZZ4md9n...
# 3     https://api.spotify.com/v1/tracks/1mSJ5YhKEuFG...
# 4     https://api.spotify.com/v1/tracks/5T5lfc7XDP1r...
# ...                                                 ...
# 7089  https://api.spotify.com/v1/tracks/3eM1OyuTO7tY...
# 7090  https://api.spotify.com/v1/tracks/75jyBlvlVkSg...
# 7091  https://api.spotify.com/v1/tracks/5U3BtEzZtKgk...
# 7092  https://api.spotify.com/v1/tracks/6s2YGDofoeyf...
# 7093  https://api.spotify.com/v1/tracks/3Z0H46wO0WYK...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3TYv...       162280
# 1     https://api.spotify.com/v1/audio-analysis/4sjo...       161111
# 2     https://api.spotify.com/v1/audio-analysis/7a3U...       183992
# 3     https://api.spotify.com/v1/audio-analysis/1mSJ...       213295
# 4     https://api.spotify.com/v1/audio-analysis/5T5l...       274000
# ...                                                 ...          ...
# 7089  https://api.spotify.com/v1/audio-analysis/3eM1...       216331
# 7090  https://api.spotify.com/v1/audio-analysis/75jy...       172253
# 7091  https://api.spotify.com/v1/audio-analysis/5U3B...       159382
# 7092  https://api.spotify.com/v1/audio-analysis/6s2Y...       208613
# 7093  https://api.spotify.com/v1/audio-analysis/3Z0H...       148148
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 7089               4
# 7090               4
# 7091               3
# 7092               4
# 7093               4
#
# [7094 rows x 18 columns]

# %%
df = tracks.join(fuller)

# %%
df
# Out:
#                     track_id                     track_name  \
# 0     3TYvJyZKCO206xrWpF3DIf                          Girls
# 1     4sjoQiP7YBPOfR9I2IWsAe                       Wine Low
# 2     7a3UBZZ4md9nJUDQbxqk7W                    Hookin' Meh
# 3     1mSJ5YhKEuFGEDq6yarGhh                        Day One
# 4     5T5lfc7XDP1rxcB4QDtZTX                   Wining Queen
# ...                      ...                            ...
# 7089  3eM1OyuTO7tYQ4dkRYiMQw            Middle of Something
# 7090  75jyBlvlVkSgjXiQDTWUeS                  Give It to Ya
# 7091  5U3BtEzZtKgkin6H5XQWcf                       Bang Bim
# 7092  6s2YGDofoeyfbJGCL8ebxN  Like Nike - Side Piece Riddim
# 7093  3Z0H46wO0WYKS73eLm1ipa                        Mad Jab
#
#                                  track_uri                    artist_name  \
# 0     spotify:track:3TYvJyZKCO206xrWpF3DIf                Break The World
# 1     spotify:track:4sjoQiP7YBPOfR9I2IWsAe                       Wine Low
# 2     spotify:track:7a3UBZZ4md9nJUDQbxqk7W                 Hooked on Soca
# 3     spotify:track:1mSJ5YhKEuFGEDq6yarGhh                 Hooked on Soca
# 4     spotify:track:5T5lfc7XDP1rxcB4QDtZTX               Project 5 Riddim
# ...                                    ...                            ...
# 7089  spotify:track:3eM1OyuTO7tYQ4dkRYiMQw           Problem Is a Problem
# 7090  spotify:track:75jyBlvlVkSgjXiQDTWUeS                  Give It to Ya
# 7091  spotify:track:5U3BtEzZtKgkin6H5XQWcf             One O'clock Riddim
# 7092  spotify:track:6s2YGDofoeyfbJGCL8ebxN  Like Nike (Side Piece Riddim)
# 7093  spotify:track:3Z0H46wO0WYKS73eLm1ipa              Planet Jab Riddim
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.778   0.767    1    -2.743     1       0.1520       0.13100
# 1            0.873   0.733    1    -4.162     1       0.1060       0.13400
# 2            0.844   0.958   11    -3.666     1       0.0727       0.16100
# 3            0.577   0.945    1    -3.420     1       0.0664       0.09050
# 4            0.926   0.781    9    -6.455     1       0.0932       0.04930
# ...            ...     ...  ...       ...   ...          ...           ...
# 7089         0.820   0.893    2    -3.251     1       0.0486       0.25900
# 7090         0.854   0.911    0    -3.957     1       0.0417       0.00458
# 7091         0.655   0.756    7    -2.557     1       0.3440       0.09530
# 7092         0.854   0.903    1    -3.453     1       0.1260       0.36600
# 7093         0.806   0.890   11    -2.501     0       0.1780       0.52000
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.0461    0.877  119.845  audio_features
# 1             0.000000    0.0854    0.713  108.022  audio_features
# 2             0.000000    0.3010    0.935  106.006  audio_features
# 3             0.000000    0.4990    0.855  131.343  audio_features
# 4             0.000306    0.0690    0.905  122.042  audio_features
# ...                ...       ...      ...      ...             ...
# 7089          0.089500    0.0942    0.526  107.998  audio_features
# 7090          0.000000    0.0267    0.638  107.927  audio_features
# 7091          0.000007    0.2550    0.775  191.764  audio_features
# 7092          0.000000    0.4190    0.849  129.964  audio_features
# 7093          0.012700    0.1360    0.713  161.976  audio_features
#
#                           id                                   uri  \
# 0     3TYvJyZKCO206xrWpF3DIf  spotify:track:3TYvJyZKCO206xrWpF3DIf
# 1     4sjoQiP7YBPOfR9I2IWsAe  spotify:track:4sjoQiP7YBPOfR9I2IWsAe
# 2     7a3UBZZ4md9nJUDQbxqk7W  spotify:track:7a3UBZZ4md9nJUDQbxqk7W
# 3     1mSJ5YhKEuFGEDq6yarGhh  spotify:track:1mSJ5YhKEuFGEDq6yarGhh
# 4     5T5lfc7XDP1rxcB4QDtZTX  spotify:track:5T5lfc7XDP1rxcB4QDtZTX
# ...                      ...                                   ...
# 7089  3eM1OyuTO7tYQ4dkRYiMQw  spotify:track:3eM1OyuTO7tYQ4dkRYiMQw
# 7090  75jyBlvlVkSgjXiQDTWUeS  spotify:track:75jyBlvlVkSgjXiQDTWUeS
# 7091  5U3BtEzZtKgkin6H5XQWcf  spotify:track:5U3BtEzZtKgkin6H5XQWcf
# 7092  6s2YGDofoeyfbJGCL8ebxN  spotify:track:6s2YGDofoeyfbJGCL8ebxN
# 7093  3Z0H46wO0WYKS73eLm1ipa  spotify:track:3Z0H46wO0WYKS73eLm1ipa
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3TYvJyZKCO20...
# 1     https://api.spotify.com/v1/tracks/4sjoQiP7YBPO...
# 2     https://api.spotify.com/v1/tracks/7a3UBZZ4md9n...
# 3     https://api.spotify.com/v1/tracks/1mSJ5YhKEuFG...
# 4     https://api.spotify.com/v1/tracks/5T5lfc7XDP1r...
# ...                                                 ...
# 7089  https://api.spotify.com/v1/tracks/3eM1OyuTO7tY...
# 7090  https://api.spotify.com/v1/tracks/75jyBlvlVkSg...
# 7091  https://api.spotify.com/v1/tracks/5U3BtEzZtKgk...
# 7092  https://api.spotify.com/v1/tracks/6s2YGDofoeyf...
# 7093  https://api.spotify.com/v1/tracks/3Z0H46wO0WYK...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3TYv...       162280
# 1     https://api.spotify.com/v1/audio-analysis/4sjo...       161111
# 2     https://api.spotify.com/v1/audio-analysis/7a3U...       183992
# 3     https://api.spotify.com/v1/audio-analysis/1mSJ...       213295
# 4     https://api.spotify.com/v1/audio-analysis/5T5l...       274000
# ...                                                 ...          ...
# 7089  https://api.spotify.com/v1/audio-analysis/3eM1...       216331
# 7090  https://api.spotify.com/v1/audio-analysis/75jy...       172253
# 7091  https://api.spotify.com/v1/audio-analysis/5U3B...       159382
# 7092  https://api.spotify.com/v1/audio-analysis/6s2Y...       208613
# 7093  https://api.spotify.com/v1/audio-analysis/3Z0H...       148148
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 7089               4
# 7090               4
# 7091               3
# 7092               4
# 7093               4
#
# [7094 rows x 22 columns]

# %%
df.to_csv('data/more_soca_done.csv')

# %% [markdown]
# # full features

# %%
df = pd.read_csv('data/working_new.csv')

# %%
ids = list(df['track_id'])

# %%
ids[0]
# Out:
# '5vNKYqDA0jFnhf7KoeBhuD'

# %%
def get_full_feats(list):

    feats = []

    for id in range(len(list)):
        r = requests.get(f"https://api.spotify.com/v1/audio-analysis/5vNKYqDA0jFnhf7KoeBhuD",
                     headers={ "Accept": "application/json", 
                              "Content-Type": "application/json", 
                              "Authorization": oath})
        dat =r.json()
        
        data = dat['track']
        
        feats.append({
                'num_samples' : data['num_samples'],
                'duration' : data['duration'],
                'sample_md5': data['sample_md5'],
                'offset_seconds': data['offset_seconds'],
                'window_seconds': data['window_seconds'],
                'analysis_sample_rate': data['analysis_sample_rate'],
                'analysis_channels': data['analysis_channels'],
                'end_of_fade_in': data['end_of_fade_in'],
                'start_of_fade_out': data['start_of_fade_out'],
                'loudness': data['loudness'],
                'tempo': data['tempo'],
                'tempo_confidence': data['tempo_confidence'],
                'time_signature': data['time_signature_confidence'],
                'key': data['key'],
                'key_confidence': data['key_confidence'],
                'mode': data['mode'],
                'mode_confidence': data['mode_confidence']
                    })
    return feats
        
#     df = pd.DataFrame(feats)
    
#     return df

# %%
data = get_full_feats(ids)

# %%
data

# %%
data_df = pd.DataFrame(data)
