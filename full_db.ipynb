# %%
import pandas as pd
import numpy as np

# %%
r_df = pd.read_csv('reggae_working.csv')
r_df.head()
# Out:
#                Unnamed: 0                          track_name  \
# 0  00P2FrG46TtBIhUBju0tqR                        Slavery Days
# 1  011xoKDagylY12ofOd3qUX                      Mixed Feelings
# 2  01N1T689bhEHqXWs3ZMZcO  Good Vibration (feat. Trevor Hall)
# 3  01rxaavCYWlFIHJJdF4PTT                       Special Guest
# 4  02O3f5M4FkBUslfjYDCOkE              Jah Jah Ah Natty Dread
#
#                       artist                    album release_date  explicit  \
# 0           Tiken Jah Fakoly                  Racines   2015-09-25     False
# 1                     Anuhea                Follow Me   2017-10-06     False
# 2                      HIRIE           Wandering Soul   2016-08-26     False
# 3               Anthony Rich      Pure Lovers, Vol. 2   2009-06-01     False
# 4  Lee Perry & The Upsetters  Return Of The Super Ape         2003     False
#
#                  track_id                             track_uri  danceability  \
# ...

# %%
d_df = pd.read_csv('bashment_working.csv')
d_df.head()
# Out:
#                Unnamed: 0  Unnamed: 0.1               track_name  \
# 0  007NH2yex3ihVts4FHr2tW           855              Full a Gyal
# 1  00rTSPtRF2LsHI39WCXRjN          1061             Phone a Ring
# 2  00yQl6VP2oHUqnrhAXEKoW           166                Lifestyle
# 3  01NRErhQZIau5ebhdXMhGs            95             Dom Pérignon
# 4  01fyhPl5A0hn1ljNPtE0ev          1514  Gyal You A Party Animal
#
#          artist            album release_date  explicit  \
# 0    Jahvillani      Full a Gyal   2019-05-15      True
# 1   Sikka Rymes     Phone a Ring   2019-11-29      True
# 2       Kranium           Rumors   2015-10-16      True
# 3       Aidonia     Dom Pérignon   2018-12-20      True
# 4  Charly Black  Jambe-An Riddim   2015-04-14     False
#
#                  track_id                             track_uri      genre  \
# 0  007NH2yex3ihVts4FHr2tW  spotify:track:007NH2yex3ihVts4FHr2tW  dancehall
# 1  00rTSPtRF2LsHI39WCXRjN  spotify:track:00rTSPtRF2LsHI39WCXRjN  dancehall
# ...

# %%
s_df = pd.read_csv('soca_working.csv')
s_df.head()
# Out:
#                Unnamed: 0  Unnamed: 0.1                track_name  \
# 0  00A8hsKelAI5N7bmcbvn9v          1119                   So Long
# 1  00BBC45AUahDMdYaJ6wjxp           797                   Mash Up
# 2  00v3qhEMB8Z8D5PU2LpDFK           832                   Toc Tic
# 3  01NRErhQZIau5ebhdXMhGs          1088              Dom Pérignon
# 4  01NjsQ8VVcaPNZPIfzhhb1          1504  X Games - Acoustic Intro
#
#             artist               album release_date  explicit  \
# 0     Nadia Batson       Get Soca 2019   2019-02-22     False
# 1           Destra  Queen of Bacchanal   2014-04-08     False
# 2        Marzville     Force It Riddim   2016-12-16     False
# 3          Aidonia        Dom Pérignon   2018-12-20      True
# 4  DJ Private Ryan  The Fizzle Project   2019-12-02     False
#
#                  track_id                             track_uri genre  ...  \
# 0  00A8hsKelAI5N7bmcbvn9v  spotify:track:00A8hsKelAI5N7bmcbvn9v  soca  ...
# ...

# %%
df = pd.concat([r_df, d_df, s_df], sort = True)

# %%
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'analysis_url','id','track_href','track_id','track_uri','uri'], inplace = True)

# %%
df.dropna()
df.reset_index()
# Out:
#       index  acousticness                           album  \
# 0         0        0.0999                         Racines
# 1         1        0.2050                       Follow Me
# 2         2        0.4700                  Wandering Soul
# 3         3        0.0987             Pure Lovers, Vol. 2
# 4         4        0.1140         Return Of The Super Ape
# ...     ...           ...                             ...
# 4833   1753        0.0995  Body Talk (feat. Chris Hierro)
# 4834   1754        0.0931                        Activate
# 4835   1755        0.0531                  Sexting Riddim
# 4836   1756        0.0869       De Boss Riddim: Soca 2015
# 4837   1757        0.0443       Everybody Fucking Ya Gyal
#
#                          artist  danceability  duration_ms  energy  explicit  \
# 0              Tiken Jah Fakoly         0.507     249787.0   0.446     False
# 1                        Anuhea         0.722     203413.0   0.681     False
# ...

# %%
df.to_csv('full_working.csv', index = False)
