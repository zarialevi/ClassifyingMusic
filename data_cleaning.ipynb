# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
onehot = OneHotEncoder()
labelencoder = LabelEncoder()

# %%
df = pd.read_csv('data/full_working.csv')
df.dropna(inplace=True)
df.drop(columns = ['Unnamed: 0', 'type','album','artist','track_name'], inplace=True)

# %%
df['genre'] = labelencoder.fit_transform(df['genre'])
df['explicit'] = labelencoder.fit_transform(df['explicit'])
df['key'] = labelencoder.fit_transform(df['key'])
df['mode'] = labelencoder.fit_transform(df['mode'])
df['time_signature'] = labelencoder.fit_transform(df['time_signature'])

# %%
year = []

for x in df['release_date']:
    year.append(x[:4])
    
df['year'] = year    
df['year'].astype('int64') 
df.drop(columns='release_date', inplace=True)

# %%
df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  explicit  genre  \
# 0        0.0999         0.507     249787.0   0.446         0      1
# 1        0.2050         0.722     203413.0   0.681         0      1
# 2        0.4700         0.602     259133.0   0.661         0      1
# 3        0.0987         0.833     234867.0   0.309         0      1
# 4        0.1140         0.621     214297.0   0.664         0      1
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000025    7    0.1060    -7.337     1       0.0587  141.647
# 1          0.000000   10    0.0501    -4.419     1       0.0330  138.008
# 2          0.003930    8    0.1460    -8.615     1       0.0631  117.884
# 3          0.000009    7    0.0819   -10.400     1       0.1050   87.047
# 4          0.000000    9    0.1240    -5.609     0       0.0734  132.220
#
#    time_signature                track_id  valence  year
# 0               2  00P2FrG46TtBIhUBju0tqR    0.285  2015
# 1               2  011xoKDagylY12ofOd3qUX    0.965  2017
# 2               2  01N1T689bhEHqXWs3ZMZcO    0.341  2016
# 3               2  01rxaavCYWlFIHJJdF4PTT    0.927  2009
# 4               2  02O3f5M4FkBUslfjYDCOkE    0.480  2003

# %%
for x in df.columns:
    xx = df[x]
    print(xx.value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       0.0999
# 1       0.2050
# 2       0.4700
# 3       0.0987
# 4       0.1140
#          ...
# 4833    0.0995
# 4834    0.0931
# 4835    0.0531
# 4836    0.0869
# 4837    0.0443
# Name: acousticness, Length: 4836, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0       0.507
# 1       0.722
# 2       0.602
# 3       0.833
# 4       0.621
#         ...
# 4833    0.754
# 4834    0.642
# 4835    0.823
# 4836    0.833
# 4837    0.773
# Name: danceability, Length: 4836, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0       249787.0
# 1       203413.0
# 2       259133.0
# 3       234867.0
# 4       214297.0
#           ...
# 4833    245701.0
# 4834    136385.0
# 4835    174405.0
# 4836    159048.0
# 4837    124683.0
# Name: duration_ms, Length: 4836, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0       0.446
# 1       0.681
# 2       0.661
# 3       0.309
# 4       0.664
#         ...
# 4833    0.932
# 4834    0.853
# 4835    0.653
# 4836    0.782
# 4837    0.748
# Name: energy, Length: 4836, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4833    0
# 4834    0
# 4835    0
# 4836    0
# 4837    1
# Name: explicit, Length: 4836, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4833    2
# 4834    2
# 4835    2
# 4836    2
# 4837    2
# Name: genre, Length: 4836, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       0.000025
# 1       0.000000
# 2       0.003930
# 3       0.000009
# 4       0.000000
#           ...
# 4833    0.000419
# 4834    0.000000
# 4835    0.000080
# 4836    0.000000
# 4837    0.000483
# Name: instrumentalness, Length: 4836, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0        7
# 1       10
# 2        8
# 3        7
# 4        9
#         ..
# 4833     8
# 4834     6
# 4835     4
# 4836     7
# 4837     1
# Name: key, Length: 4836, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       0.1060
# 1       0.0501
# 2       0.1460
# 3       0.0819
# 4       0.1240
#          ...
# 4833    0.2010
# 4834    0.1180
# 4835    0.0904
# 4836    0.1100
# 4837    0.0677
# Name: liveness, Length: 4836, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0       -7.337
# 1       -4.419
# 2       -8.615
# 3      -10.400
# 4       -5.609
#          ...
# 4833    -5.073
# 4834    -4.059
# 4835    -4.378
# 4836    -3.743
# 4837    -7.540
# Name: loudness, Length: 4836, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0       1
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 4833    1
# 4834    1
# 4835    0
# 4836    1
# 4837    0
# Name: mode, Length: 4836, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       0.0587
# 1       0.0330
# 2       0.0631
# 3       0.1050
# 4       0.0734
#          ...
# 4833    0.0590
# 4834    0.2790
# 4835    0.0402
# 4836    0.2810
# 4837    0.2570
# Name: speechiness, Length: 4836, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0       141.647
# 1       138.008
# 2       117.884
# 3        87.047
# 4       132.220
#          ...
# 4833    130.017
# 4834    113.931
# 4835    100.023
# 4836    157.037
# 4837    157.874
# Name: tempo, Length: 4836, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 4833    2
# 4834    2
# 4835    2
# 4836    2
# 4837    2
# Name: time_signature, Length: 4836, dtype: int64>
# <bound method IndexOpsMixin.value_counts of 0       00P2FrG46TtBIhUBju0tqR
# 1       011xoKDagylY12ofOd3qUX
# 2       01N1T689bhEHqXWs3ZMZcO
# 3       01rxaavCYWlFIHJJdF4PTT
# 4       02O3f5M4FkBUslfjYDCOkE
#                  ...
# 4833    7vS7knISRY4QEk6vzeOGk3
# 4834    7vy0S9WfaUoC4SZE6DO65M
# 4835    7xMICFkbPw6ClC4jENSX3U
# 4836    7xW9kuak6ViVF8Z9Ih15ZM
# 4837    7xiaGjbAhXFO8bkjLyfdcN
# Name: track_id, Length: 4836, dtype: object>
# <bound method IndexOpsMixin.value_counts of 0       0.285
# 1       0.965
# 2       0.341
# 3       0.927
# 4       0.480
#         ...
# 4833    0.851
# 4834    0.811
# 4835    0.588
# 4836    0.820
# 4837    0.511
# Name: valence, Length: 4836, dtype: float64>
# <bound method IndexOpsMixin.value_counts of 0       2015
# 1       2017
# 2       2016
# 3       2009
# 4       2003
#         ...
# 4833    2015
# 4834    2018
# 4835    2019
# 4836    2015
# 4837    2019
# Name: year, Length: 4836, dtype: object>

# %%
df.to_csv('data/working_clean.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4836 entries, 0 to 4837
# Data columns (total 17 columns):
# acousticness        4836 non-null float64
# danceability        4836 non-null float64
# duration_ms         4836 non-null float64
# energy              4836 non-null float64
# explicit            4836 non-null int64
# genre               4836 non-null int64
# instrumentalness    4836 non-null float64
# key                 4836 non-null int64
# liveness            4836 non-null float64
# loudness            4836 non-null float64
# mode                4836 non-null int64
# speechiness         4836 non-null float64
# tempo               4836 non-null float64
# time_signature      4836 non-null int64
# track_id            4836 non-null object
# valence             4836 non-null float64
# year                4836 non-null object
# dtypes: float64(10), int64(5), object(2)
# memory usage: 680.1+ KB

# %%
df['genre'] = df['genre'].astype('category')

# %%
lst = ['genre','key','mode','year']

for x in lst:
    df[x] = df[x].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4836 entries, 0 to 4837
# Data columns (total 17 columns):
# acousticness        4836 non-null float64
# danceability        4836 non-null float64
# duration_ms         4836 non-null float64
# energy              4836 non-null float64
# explicit            4836 non-null int64
# genre               4836 non-null category
# instrumentalness    4836 non-null float64
# key                 4836 non-null category
# liveness            4836 non-null float64
# loudness            4836 non-null float64
# mode                4836 non-null category
# speechiness         4836 non-null float64
# tempo               4836 non-null float64
# time_signature      4836 non-null int64
# track_id            4836 non-null object
# valence             4836 non-null float64
# year                4836 non-null category
# dtypes: category(4), float64(10), int64(2), object(1)
# memory usage: 551.3+ KB

# %%
df['track_id'] = df['track_id'].astype('str')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-c5b5ea3ea3b9> in <module>
# ----> 1 df['track_id'] = df['track_id'].astype('int32')
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     705         # work around NumPy brokenness, #1987
#     706         if np.issubdtype(dtype.type, np.integer):
# --> 707             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     708
#     709         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '00P2FrG46TtBIhUBju0tqR'
